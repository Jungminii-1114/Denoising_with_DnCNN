# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
from torchvision.transforms import transforms
import torchvision.transforms.functional as TF
import torch.optim as optim

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import scipy.io
from PIL import Image
import cv2

import random

# %%
import os
from google.colab import userdata

try:
    os.environ['KAGGLE_USERNAME'] = "lufthansa454"
    os.environ['KAGGLE_KEY'] = "KGAT_2c8ff1dfe135f6b618f19f04faedfe72"           # 예: "2893..." (긴 숫자+문자 조합)
    print("User Info being set")
except:
    print("User info has not been set")


# !kaggle datasets download -d balraj98/berkeley-segmentation-dataset-500-bsds500

# !unzip -q berkeley-segmentation-dataset-500-bsds500.zip -d ./bsds500

print("Dataset Downlaod and Unzip Complete")
# Out:
# User Info being set
# Dataset URL: https://www.kaggle.com/datasets/balraj98/berkeley-segmentation-dataset-500-bsds500
# License(s): other
# berkeley-segmentation-dataset-500-bsds500.zip: Skipping, found more recently modified local copy (use --force to force download)
# replace ./bsds500/ground_truth/test/100007.mat? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
# Dataset Downlaod and Unzip Complete

# %%
head_path = "/content/bsds500"
ground_truth_path = os.path.join(head_path, "ground_truth")
# 해당 폴더 내의 파일들은 Segmentation 혹은 Edge Detection, Rand Error / Warping Error 평가 시에 사용되는 데이터로,
# 본 파일에서 진행 할 Denoising에서는 사용하지 않는다.

images_path = os.path.join(head_path, "images")
files = os.listdir(head_path)
print(files)
print(os.listdir(ground_truth_path))
print(os.listdir(images_path))

num_test_img = len(os.listdir(os.path.join(images_path, "test")))
num_train_img = len(os.listdir(os.path.join(images_path, "train")))
num_val_img = len(os.listdir(os.path.join(images_path, "val")))

print(f"\nTest 이미지 개수 : {num_test_img}")
print(f"Train 이미지 개수 : {num_train_img}")
print(f"Valid 이미지 개수 : {num_val_img}")
# Out:
# ['ground_truth', 'images']
# ['val', 'train', 'test']
# ['val', 'train', 'test']
#
# Test 이미지 개수 : 201
# Train 이미지 개수 : 201
# Valid 이미지 개수 : 101

# %%
train_path = os.path.join(images_path, "train")
test_path = os.path.join(images_path, "test")
val_path = os.path.join(images_path, "val")

# %%
image_files = os.listdir(train_path)

image_files = [f for f in image_files if f.lower().endswith('.jpg')] # 'Thunbs.db' 파일도 섞여있기 떄문에 사진 파일만 필터링


first_image_filename = image_files[0]
first_image_path = os.path.join(train_path, first_image_filename)
img = Image.open(first_image_path)
plt.imshow(img)
print(f"Image format : {img.format}")
print(f"Image size : {img.size}")
print(f"Image channel : {img.mode}")
plt.show()
# Out:
# Image format : JPEG
# Image size : (481, 321)
# Image channel : RGB

# %%
train_transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),
    transforms.RandomCrop(40),

    transforms.RandomChoice([
        transforms.RandomRotation((0, 0)),
        transforms.RandomRotation((90, 90)),
        transforms.RandomRotation((180, 180)),
        transforms.RandomRotation((270, 270))
    ]),

    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
    transforms.ToTensor()
])

val_transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),
    transforms.ToTensor()
])

# %%
class CustomDataset(Dataset):
    def __init__(self, images_path, mode, noise_factor, transform=None):
        self.transform = transform
        self.images_path = images_path
        self.mode = mode
        self.noise_factor = noise_factor

        self.img_files = sorted(os.listdir(self.images_path))
        self.img_files = [f for f in self.img_files if f.lower().endswith('.jpg')]

    def __len__(self):
        #return len(os.listdir(self.img_files))
        return len(self.img_files)

    def __getitem__(self, idx):
        clean_image = Image.open(os.path.join(self.images_path, self.img_files[idx])).convert("RGB")
        #clean_image = Image.open(self.img_files[idx]).convert("L")
        clean_image = Image.open(os.path.join(self.images_path, self.img_files[idx])).convert("L")
        if self.transform:
            clean_image = self.transform(clean_image)

            # 여기서 noise 적용하기

            sigma = self.noise_factor / 255.0
            noise = torch.randn_like(clean_image) * sigma
            noisy_image = clean_image + noise
            noisy_image = torch.clamp(noisy_image, 0.0, 1.0)

        return noisy_image, clean_image

# %%
train_dataset = CustomDataset(train_path, mode='train', noise_factor=50, transform=train_transform)
test_dataset = CustomDataset(test_path, mode='test', noise_factor=50, transform=val_transform)
val_dataset = CustomDataset(val_path, mode='val', noise_factor=50, transform=val_transform)

# %%
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False, num_workers=0)
val_loader = DataLoader(val_dataset, batch_size=1, shuffle=False, num_workers=0)

# %%
dataiter = iter(train_loader)
noisy_images, clean_images = next(dataiter)

noisy_images.shape

img_show = noisy_images[0].squeeze(0)
plt.imshow(img_show, cmap='gray')
plt.show()

# %%
def analyze(dataset, idx=0):
    noisy_tensor, clean_tensor = dataset[idx]

    noise_only_tensor = noisy_tensor - clean_tensor

    clean_flat = clean_tensor.flatten().numpy()
    noisy_flat = noisy_tensor.flatten().numpy()
    noise_flat = noise_only_tensor.flatten().numpy()

    # 행 열 순서

    plt.figure(figsize=(15, 10))

    plt.subplot(231)
    plt.imshow(clean_tensor.squeeze().numpy(), cmap='gray')
    plt.title("Clean Patch", fontsize=20)

    plt.subplot(232)
    plt.imshow(noisy_tensor.squeeze().numpy(), cmap='gray')
    plt.title(f"Noisy Patch (Sigma={dataset.noise_factor})", fontsize=20)

    plt.subplot(233)
    vis_noise = noise_only_tensor.squeeze().numpy()
    vis_noise = (vis_noise - vis_noise.mean()) / (vis_noise.max() - vis_noise.min())
    plt.imshow(vis_noise, cmap='gray')
    plt.title("Noise Only (Visualized)", fontsize=20)

    plt.subplot(234)
    plt.hist(clean_flat, bins=100, color='green')
    plt.title("Clean Histogram", fontsize=20)
    plt.xlim(0, 1)

    plt.subplot(235)
    plt.hist(noisy_flat, bins=220, color='red')
    plt.title("Noisy Histogram", fontsize=20)
    plt.xlim(0,1)

    plt.subplot(236)
    plt.hist(noise_flat, bins=220, color='blue')
    plt.title("Noise Only Histogram", fontsize=20)
    sigma_scale = dataset.noise_factor / 255.0
    plt.xlim(-3*sigma_scale, 3*sigma_scale)
    plt.axvline(0, color='k', linestyle='dashed', linewidth=2)


    plt.show()

analyze(train_dataset, 0)

# %%
class DnCNN(nn.Module):
    def __init__(self, n_channels=1, n_layers=17):
        super().__init__()

        # Stem
        self.layer1 = nn.Sequential(
            nn.Conv2d(n_channels, 64, 3, padding=1),
            nn.ReLU(inplace=True)
        )

        # Body (수정 필요)
        layers=[]
        for _ in range(n_layers - 2):
            layers.append(nn.Conv2d(64, 64, kernel_size=3, padding=1, bias=False))
            layers.append(nn.BatchNorm2d(64))
            layers.append(nn.ReLU(inplace=True))
        self.body = nn.Sequential(*layers) # Unpack해서 각각으로 만들어주기

        # Head
        self.last_layer = nn.Sequential(
            nn.Conv2d(64, n_channels, 3, padding=1)
        )

    def forward(self, x):
        out = self.layer1(x)

        #x = self.body() # layer2 ~ layer 16
        out = self.body(out)

        out = self.last_layer(out)

        return out # (입력 - 예측노이즈)

# %%
def weights_init_kaiming(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        # Kaiming Normal (He 초기화) - ReLU를 쓰는 모델에 적합
        nn.init.kaiming_normal_(m.weight.data, a=0, mode='fan_in')
    elif classname.find('Linear') != -1:
        nn.init.kaiming_normal_(m.weight.data, a=0, mode='fan_in')
    elif classname.find('BatchNorm') != -1:
        # BatchNorm은 weight 1, bias 0으로 초기화
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0.0)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = DnCNN().to(device)
model.apply(weights_init_kaiming)
# Out:
# DnCNN(
#   (layer1): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#   )
#   (body): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU(inplace=True)
#     (9): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): ReLU(inplace=True)
#     (12): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (13): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): ReLU(inplace=True)
#     (15): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (16): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (17): ReLU(inplace=True)
#     (18): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (19): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (20): ReLU(inplace=True)
#     (21): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (22): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (23): ReLU(inplace=True)
#     (24): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (25): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (26): ReLU(inplace=True)
#     (27): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (28): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (29): ReLU(inplace=True)
#     (30): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (31): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (32): ReLU(inplace=True)
#     (33): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (34): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (35): ReLU(inplace=True)
#     (36): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (37): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (38): ReLU(inplace=True)
#     (39): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (40): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (41): ReLU(inplace=True)
#     (42): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (43): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (44): ReLU(inplace=True)
#   )
#   (last_layer): Sequential(
#     (0): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )

# %%
n_epochs = 100

criterion = nn.MSELoss(reduction='mean')
optimizer_Adam = optim.Adam(model.parameters(), lr = 0.0001)
optimizer_SGD = optim.SGD(model.parameters(), lr=0.1, momentum=0.9)

# 0.1에서 시작, 50 epoch동안 0.0001로 감소
#scheduler_ex = optim.lr_scheduler.ExponentialLR(optimizer_Adam, gamma=0.871)
#scheduler_ms = optim.lr_scheduler.MultiStepLR(optimizer_Adam, milestones=[30, 40], gamma=0.1)
scheduler_step = optim.lr_scheduler.StepLR(optimizer_Adam, step_size=10, gamma=0.1)
#scheduler_lambda = optim.lr_scheduler.LambdaLR(optimizer_Adam, lr_lambda=lambda epoch: 0.871 ** epoch)


modle_test = nn.Linear(10, 5)
#Exponential Scheduler, Lambda Scheduler 사용해서 비교해보기

# %%
INF = 1000
def calculate_PSNR(image1, image2):
    mse = torch.mean((image1 - image2) ** 2)
    if mse == 0:
        return INF
    return 10 * torch.log10(1.0 / mse) # R은 픽셀의 최대값으로, 8비트 unsigned int : 255, double/float : 1

# %%
def train_Adam(model, train_loader, optimizer_Adam, criterion, epoch):
    model.train()

    running_loss = 0.0
    running_psnr = 0.0

    for inputs, targets in train_loader:
        inputs, targets = inputs.to(device), targets.to(device)
        # inputs : Noisy, targets : Clean Image
        # loss 구할 때 targets가 깨끗한 이미지로 들어가면 안됨.
        # Loss = MSE(output, clean_img) : X
        # Loss = MSE(output, (noisy - clean)) : O

        optimizer_Adam.zero_grad()
        outputs = model(inputs)

        #loss = criterion(outputs, targets)
        real_noise = inputs - targets # (Noisy - Clean)
        loss = criterion(outputs, real_noise)

        denoised_img = inputs - outputs # (Noisy - Denoised)
        #denoised_img = torch.clamp(denoised_img, 0.0, 1.0) # 중요!!!

        # Train에서는 clamp를 적용하지 말아야 한다??

        loss.backward()
        optimizer_Adam.step()

        running_loss += loss.item()
        running_psnr += calculate_PSNR(denoised_img, targets).item()

    epoch_loss = running_loss / len(train_loader)
    epoch_psnr = running_psnr / len(train_loader)

    print(f"\nEpoch {epoch} Train - Loss : {epoch_loss:.6f}, PSNR : {epoch_psnr:.2f} dB")
    return epoch_loss, epoch_psnr

# %%
def val_Adam(model, val_loader, optimizer_Adam, criterion, epoch):
    model.eval()

    val_loss = 0.0
    val_psnr = 0.0

    with torch.no_grad():
        for inputs, targets in val_loader:
            inputs, targets = inputs.to(device), targets.to(device)

            outputs = model(inputs)
            #loss = criterion(outputs, targets)
            real_noise = inputs - targets
            loss = criterion(outputs, real_noise)

            denoised_img = inputs - outputs
            #denoised_img = torch.clamp(denoised_img, 0.0, 1.0) # GPT :

            val_loss += loss.item()
            val_psnr += calculate_PSNR(denoised_img, targets).item()
    val_avg_loss = val_loss / len(val_loader)
    val_avg_psnr = val_psnr / len(val_loader)

    print(f"Epoch {epoch} Valid - Loss : {val_avg_loss:.6f}, PSNR : {val_avg_psnr:.2f} dB\n\n\n")
    #print(f"Validation inputs : {inputs.max()}")
    return val_avg_loss, val_avg_psnr

# %%
def test_Adam(model, test_loader, optimizer_Adam, criterion, epoch):
    model.eval()

    test_loss = 0.0
    test_psnr = 0.0

    with torch.no_grad():
        for inputs, targets in test_loader:
            inputs, targets = inputs.to(device), targets.to(device)

            outputs = model(inputs)

            real_noise = inputs - targets
            loss = criterion(outputs, real_noise)

            denoised_img = inputs - outputs
            #denoised_img = torch.clamp(denoised_img, 0.0, 1.0)

            test_loss += loss.item()
            test_psnr += calculate_PSNR(denoised_img, targets).item()
    avg_loss = test_loss / len(test_loader)
    avg_psnr = test_psnr / len(test_loader)

    print(f"Epoch {epoch} Test - Loss : {avg_loss:.6f}, PSNR : {avg_psnr:.2f} dB")
    return avg_loss, avg_psnr

# %%
best_psnr = 0.0
best_model_wts = None

train_loss = []
train_psnr = []
val_psnr_hist = []

for epoch in range(n_epochs):
    loss, psnr = train_Adam(model, train_loader, optimizer_Adam, criterion, epoch+1)
    train_loss.append(loss)
    train_psnr.append(psnr)

    val_loss_epoch, val_psnr_epoch = val_Adam(model, val_loader, optimizer_Adam, criterion, epoch+1)
    val_psnr_hist.append(val_psnr_epoch)

    if val_psnr_epoch > best_psnr:
        best_psnr = val_psnr_epoch
        best_model_wts = model.state_dict()

    #scheduler_ms.step()
    #scheduler_step.step()
    #scheduler_lambda.step()
    current_lr = optimizer_Adam.param_groups[0]['lr']
    print(f"Current Learning Rate : {current_lr}")

model.load_state_dict(best_model_wts)
# Out:
# Epoch 1 Train - Loss : 0.676328, PSNR : 1.71 dB
# Epoch 1 Valid - Loss : 0.061370, PSNR : 12.13 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 2 Train - Loss : 0.532398, PSNR : 2.75 dB
# Epoch 2 Valid - Loss : 0.241064, PSNR : 7.20 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 3 Train - Loss : 0.395456, PSNR : 4.04 dB
# Epoch 3 Valid - Loss : 0.480920, PSNR : 4.60 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 4 Train - Loss : 0.293083, PSNR : 5.34 dB
# Epoch 4 Valid - Loss : 0.767652, PSNR : 3.16 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 5 Train - Loss : 0.213514, PSNR : 6.74 dB
# Epoch 5 Valid - Loss : 0.449202, PSNR : 4.82 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 6 Train - Loss : 0.157041, PSNR : 8.05 dB
# Epoch 6 Valid - Loss : 0.347361, PSNR : 5.89 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 7 Train - Loss : 0.116202, PSNR : 9.37 dB
# Epoch 7 Valid - Loss : 0.232196, PSNR : 7.31 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 8 Train - Loss : 0.086121, PSNR : 10.66 dB
# Epoch 8 Valid - Loss : 0.255517, PSNR : 7.87 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 9 Train - Loss : 0.068464, PSNR : 11.66 dB
# Epoch 9 Valid - Loss : 0.133315, PSNR : 9.73 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 10 Train - Loss : 0.056588, PSNR : 12.48 dB
# Epoch 10 Valid - Loss : 0.079350, PSNR : 11.37 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 11 Train - Loss : 0.051960, PSNR : 12.86 dB
# Epoch 11 Valid - Loss : 0.067183, PSNR : 12.03 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 12 Train - Loss : 0.046200, PSNR : 13.36 dB
# Epoch 12 Valid - Loss : 0.053701, PSNR : 12.84 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 13 Train - Loss : 0.043755, PSNR : 13.59 dB
# Epoch 13 Valid - Loss : 0.050874, PSNR : 13.13 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 14 Train - Loss : 0.041280, PSNR : 13.85 dB
# Epoch 14 Valid - Loss : 0.043839, PSNR : 13.65 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 15 Train - Loss : 0.038949, PSNR : 14.10 dB
# Epoch 15 Valid - Loss : 0.042144, PSNR : 13.83 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 16 Train - Loss : 0.039359, PSNR : 14.07 dB
# Epoch 16 Valid - Loss : 0.040100, PSNR : 14.02 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 17 Train - Loss : 0.037526, PSNR : 14.26 dB
# Epoch 17 Valid - Loss : 0.038877, PSNR : 14.15 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 18 Train - Loss : 0.036371, PSNR : 14.40 dB
# Epoch 18 Valid - Loss : 0.038589, PSNR : 14.21 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 19 Train - Loss : 0.035727, PSNR : 14.47 dB
# Epoch 19 Valid - Loss : 0.035867, PSNR : 14.47 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 20 Train - Loss : 0.034911, PSNR : 14.57 dB
# Epoch 20 Valid - Loss : 0.034714, PSNR : 14.61 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 21 Train - Loss : 0.034548, PSNR : 14.62 dB
# Epoch 21 Valid - Loss : 0.034030, PSNR : 14.69 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 22 Train - Loss : 0.034861, PSNR : 14.58 dB
# Epoch 22 Valid - Loss : 0.033872, PSNR : 14.72 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 23 Train - Loss : 0.033904, PSNR : 14.70 dB
# Epoch 23 Valid - Loss : 0.034214, PSNR : 14.68 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 24 Train - Loss : 0.033026, PSNR : 14.81 dB
# Epoch 24 Valid - Loss : 0.033156, PSNR : 14.81 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 25 Train - Loss : 0.033326, PSNR : 14.77 dB
# Epoch 25 Valid - Loss : 0.032487, PSNR : 14.89 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 26 Train - Loss : 0.032098, PSNR : 14.94 dB
# Epoch 26 Valid - Loss : 0.031996, PSNR : 14.96 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 27 Train - Loss : 0.033362, PSNR : 14.77 dB
# Epoch 27 Valid - Loss : 0.031642, PSNR : 15.01 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 28 Train - Loss : 0.032279, PSNR : 14.91 dB
# Epoch 28 Valid - Loss : 0.031933, PSNR : 14.97 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 29 Train - Loss : 0.032881, PSNR : 14.83 dB
# Epoch 29 Valid - Loss : 0.032759, PSNR : 14.88 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 30 Train - Loss : 0.031845, PSNR : 14.97 dB
# Epoch 30 Valid - Loss : 0.031903, PSNR : 14.98 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 31 Train - Loss : 0.031021, PSNR : 15.08 dB
# Epoch 31 Valid - Loss : 0.030369, PSNR : 15.19 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 32 Train - Loss : 0.031447, PSNR : 15.03 dB
# Epoch 32 Valid - Loss : 0.029933, PSNR : 15.25 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 33 Train - Loss : 0.030926, PSNR : 15.10 dB
# Epoch 33 Valid - Loss : 0.029769, PSNR : 15.28 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 34 Train - Loss : 0.032125, PSNR : 14.94 dB
# Epoch 34 Valid - Loss : 0.030124, PSNR : 15.22 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 35 Train - Loss : 0.030471, PSNR : 15.16 dB
# Epoch 35 Valid - Loss : 0.029440, PSNR : 15.32 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 36 Train - Loss : 0.030312, PSNR : 15.19 dB
# Epoch 36 Valid - Loss : 0.029103, PSNR : 15.37 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 37 Train - Loss : 0.030207, PSNR : 15.20 dB
# Epoch 37 Valid - Loss : 0.028969, PSNR : 15.40 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 38 Train - Loss : 0.030050, PSNR : 15.23 dB
# Epoch 38 Valid - Loss : 0.028896, PSNR : 15.41 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 39 Train - Loss : 0.029839, PSNR : 15.25 dB
# Epoch 39 Valid - Loss : 0.028302, PSNR : 15.50 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 40 Train - Loss : 0.029444, PSNR : 15.31 dB
# Epoch 40 Valid - Loss : 0.028132, PSNR : 15.52 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 41 Train - Loss : 0.028477, PSNR : 15.46 dB
# Epoch 41 Valid - Loss : 0.027626, PSNR : 15.60 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 42 Train - Loss : 0.028891, PSNR : 15.40 dB
# Epoch 42 Valid - Loss : 0.027225, PSNR : 15.67 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 43 Train - Loss : 0.028393, PSNR : 15.47 dB
# Epoch 43 Valid - Loss : 0.026928, PSNR : 15.71 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 44 Train - Loss : 0.028754, PSNR : 15.42 dB
# Epoch 44 Valid - Loss : 0.026957, PSNR : 15.71 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 45 Train - Loss : 0.027788, PSNR : 15.56 dB
# Epoch 45 Valid - Loss : 0.026490, PSNR : 15.79 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 46 Train - Loss : 0.027724, PSNR : 15.57 dB
# Epoch 46 Valid - Loss : 0.026018, PSNR : 15.86 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 47 Train - Loss : 0.027497, PSNR : 15.61 dB
# Epoch 47 Valid - Loss : 0.025816, PSNR : 15.90 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 48 Train - Loss : 0.027773, PSNR : 15.57 dB
# Epoch 48 Valid - Loss : 0.025579, PSNR : 15.94 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 49 Train - Loss : 0.027139, PSNR : 15.67 dB
# Epoch 49 Valid - Loss : 0.025253, PSNR : 15.99 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 50 Train - Loss : 0.026673, PSNR : 15.74 dB
# Epoch 50 Valid - Loss : 0.024695, PSNR : 16.09 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 51 Train - Loss : 0.026609, PSNR : 15.75 dB
# Epoch 51 Valid - Loss : 0.024634, PSNR : 16.10 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 52 Train - Loss : 0.026481, PSNR : 15.77 dB
# Epoch 52 Valid - Loss : 0.024740, PSNR : 16.08 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 53 Train - Loss : 0.026499, PSNR : 15.77 dB
# Epoch 53 Valid - Loss : 0.024361, PSNR : 16.15 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 54 Train - Loss : 0.025964, PSNR : 15.86 dB
# Epoch 54 Valid - Loss : 0.024198, PSNR : 16.18 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 55 Train - Loss : 0.026226, PSNR : 15.82 dB
# Epoch 55 Valid - Loss : 0.024259, PSNR : 16.17 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 56 Train - Loss : 0.025491, PSNR : 15.94 dB
# Epoch 56 Valid - Loss : 0.024316, PSNR : 16.16 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 57 Train - Loss : 0.024874, PSNR : 16.05 dB
# Epoch 57 Valid - Loss : 0.023475, PSNR : 16.31 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 58 Train - Loss : 0.024120, PSNR : 16.18 dB
# Epoch 58 Valid - Loss : 0.024033, PSNR : 16.22 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 59 Train - Loss : 0.024848, PSNR : 16.05 dB
# Epoch 59 Valid - Loss : 0.023454, PSNR : 16.32 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 60 Train - Loss : 0.024400, PSNR : 16.13 dB
# Epoch 60 Valid - Loss : 0.022831, PSNR : 16.43 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 61 Train - Loss : 0.024585, PSNR : 16.10 dB
# Epoch 61 Valid - Loss : 0.022539, PSNR : 16.49 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 62 Train - Loss : 0.024596, PSNR : 16.10 dB
# Epoch 62 Valid - Loss : 0.022823, PSNR : 16.44 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 63 Train - Loss : 0.024281, PSNR : 16.15 dB
# Epoch 63 Valid - Loss : 0.022210, PSNR : 16.56 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 64 Train - Loss : 0.023440, PSNR : 16.30 dB
# Epoch 64 Valid - Loss : 0.022665, PSNR : 16.47 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 65 Train - Loss : 0.022786, PSNR : 16.43 dB
# Epoch 65 Valid - Loss : 0.021342, PSNR : 16.73 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 66 Train - Loss : 0.023149, PSNR : 16.36 dB
# Epoch 66 Valid - Loss : 0.021248, PSNR : 16.75 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 67 Train - Loss : 0.022974, PSNR : 16.39 dB
# Epoch 67 Valid - Loss : 0.021157, PSNR : 16.77 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 68 Train - Loss : 0.023031, PSNR : 16.38 dB
# Epoch 68 Valid - Loss : 0.020982, PSNR : 16.81 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 69 Train - Loss : 0.022633, PSNR : 16.45 dB
# Epoch 69 Valid - Loss : 0.020933, PSNR : 16.82 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 70 Train - Loss : 0.023071, PSNR : 16.37 dB
# Epoch 70 Valid - Loss : 0.021370, PSNR : 16.73 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 71 Train - Loss : 0.022081, PSNR : 16.56 dB
# Epoch 71 Valid - Loss : 0.020494, PSNR : 16.91 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 72 Train - Loss : 0.022299, PSNR : 16.52 dB
# Epoch 72 Valid - Loss : 0.021406, PSNR : 16.74 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 73 Train - Loss : 0.022080, PSNR : 16.56 dB
# Epoch 73 Valid - Loss : 0.020189, PSNR : 16.97 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 74 Train - Loss : 0.021451, PSNR : 16.69 dB
# Epoch 74 Valid - Loss : 0.020248, PSNR : 16.96 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 75 Train - Loss : 0.021551, PSNR : 16.67 dB
# Epoch 75 Valid - Loss : 0.019674, PSNR : 17.09 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 76 Train - Loss : 0.020777, PSNR : 16.82 dB
# Epoch 76 Valid - Loss : 0.019434, PSNR : 17.14 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 77 Train - Loss : 0.021510, PSNR : 16.69 dB
# Epoch 77 Valid - Loss : 0.019907, PSNR : 17.04 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 78 Train - Loss : 0.021169, PSNR : 16.75 dB
# Epoch 78 Valid - Loss : 0.019349, PSNR : 17.16 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 79 Train - Loss : 0.021076, PSNR : 16.77 dB
# Epoch 79 Valid - Loss : 0.018928, PSNR : 17.26 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 80 Train - Loss : 0.021560, PSNR : 16.67 dB
# Epoch 80 Valid - Loss : 0.019798, PSNR : 17.08 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 81 Train - Loss : 0.020567, PSNR : 16.87 dB
# Epoch 81 Valid - Loss : 0.019088, PSNR : 17.22 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 82 Train - Loss : 0.020507, PSNR : 16.89 dB
# Epoch 82 Valid - Loss : 0.019403, PSNR : 17.17 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 83 Train - Loss : 0.020153, PSNR : 16.96 dB
# Epoch 83 Valid - Loss : 0.018115, PSNR : 17.45 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 84 Train - Loss : 0.020371, PSNR : 16.92 dB
# Epoch 84 Valid - Loss : 0.018132, PSNR : 17.44 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 85 Train - Loss : 0.020489, PSNR : 16.89 dB
# Epoch 85 Valid - Loss : 0.017983, PSNR : 17.48 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 86 Train - Loss : 0.019898, PSNR : 17.01 dB
# Epoch 86 Valid - Loss : 0.017800, PSNR : 17.53 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 87 Train - Loss : 0.020243, PSNR : 16.94 dB
# Epoch 87 Valid - Loss : 0.017718, PSNR : 17.55 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 88 Train - Loss : 0.019655, PSNR : 17.07 dB
# Epoch 88 Valid - Loss : 0.019206, PSNR : 17.25 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 89 Train - Loss : 0.019099, PSNR : 17.20 dB
# Epoch 89 Valid - Loss : 0.017275, PSNR : 17.66 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 90 Train - Loss : 0.019233, PSNR : 17.16 dB
# Epoch 90 Valid - Loss : 0.016996, PSNR : 17.73 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 91 Train - Loss : 0.018495, PSNR : 17.33 dB
# Epoch 91 Valid - Loss : 0.016857, PSNR : 17.77 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 92 Train - Loss : 0.018875, PSNR : 17.25 dB
# Epoch 92 Valid - Loss : 0.016617, PSNR : 17.83 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 93 Train - Loss : 0.018917, PSNR : 17.23 dB
# Epoch 93 Valid - Loss : 0.016684, PSNR : 17.81 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 94 Train - Loss : 0.019131, PSNR : 17.19 dB
# Epoch 94 Valid - Loss : 0.016765, PSNR : 17.79 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 95 Train - Loss : 0.019181, PSNR : 17.18 dB
# Epoch 95 Valid - Loss : 0.016947, PSNR : 17.75 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 96 Train - Loss : 0.017882, PSNR : 17.48 dB
# Epoch 96 Valid - Loss : 0.016373, PSNR : 17.89 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 97 Train - Loss : 0.018278, PSNR : 17.39 dB
# Epoch 97 Valid - Loss : 0.016419, PSNR : 17.88 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 98 Train - Loss : 0.017828, PSNR : 17.50 dB
# Epoch 98 Valid - Loss : 0.016062, PSNR : 17.98 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 99 Train - Loss : 0.018267, PSNR : 17.38 dB
# Epoch 99 Valid - Loss : 0.016167, PSNR : 17.95 dB
#
#
#
# Current Learning Rate : 0.0001
#
# Epoch 100 Train - Loss : 0.017686, PSNR : 17.53 dB
# Epoch 100 Valid - Loss : 0.016581, PSNR : 17.86 dB
#
#
#
# Current Learning Rate : 0.0001
# <All keys matched successfully>

# %%
plt.figure(figsize=(12, 10))
plt.subplot(211)
plt.plot(range(1, n_epochs+1), train_loss, label='Train Loss', color='blue', marker='o')
plt.title("Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True)
plt.legend()

plt.subplot(212)
plt.plot(range(1, n_epochs+1), train_psnr, label='Train PSNR', color='green', marker='*')
plt.plot(range(1, n_epochs+1), val_psnr_hist, label='Val PSNR', color='y', marker='o')
plt.title("Train / Valid PSNR")
plt.xlabel("Epoch")
plt.ylabel("PSNR (dB)")
plt.grid(True)
plt.legend()

# %%
def print_denoised(model, val_loader, num_samples=3):
    model.eval()

    data_iter = iter(val_loader)
    plt.figure(figsize=(15, 5 * num_samples))
    for i in range(num_samples):
        try:
            inputs, targets = next(data_iter)
        except:
            break
        inputs, targets = inputs.to(device), targets.to(device)
        with torch.no_grad():
            outputs = model(inputs)
            denoised_img = inputs - outputs
            denoised_img = torch.clamp(denoised_img, 0.0, 1.0)

        inputs_np = inputs[0].cpu()
        targets_np = targets[0].cpu()
        denoised_np = denoised_img[0].cpu()

        psnr_noisy = calculate_PSNR(inputs_np, targets_np)
        psnr_denoised = calculate_PSNR(denoised_np, targets_np)

        clean_show = targets_np.permute(1, 2, 0).squeeze().numpy()
        noisy_show = inputs_np.permute(1, 2, 0).squeeze().numpy()
        denoised_show = denoised_np.permute(1, 2, 0).squeeze().numpy()

        plt.subplot(num_samples, 3, i*3 +1)
        plt.imshow(clean_show, cmap='gray')
        plt.title(f"Clean (Ground Truth)")
        plt.axis()

        plt.subplot(num_samples, 3, i*3 +2)
        plt.imshow(noisy_show, cmap='gray')
        plt.title(f"Noisy Input\nPSNR : {psnr_noisy:.2f}dB")
        plt.axis()

        plt.subplot(num_samples, 3, i*3 +3)
        plt.imshow(denoised_show, cmap='gray')
        plt.title(f"Denoised Output\nPSNR : {psnr_denoised:.2f}dB")
        plt.axis()

    plt.tight_layout()
    plt.show()

print_denoised(model, val_loader, num_samples=3)
