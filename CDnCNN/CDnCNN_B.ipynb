# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
from torchvision.transforms import transforms
import torchvision.transforms.functional as TF
import torch.optim as optim

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import cv2
import random
import os
from google.colab import userdata

# %%
from google.colab import userdata
import os

# Colab Secrets에서 KAGGLE_USERNAME과 KAGGLE_KEY를 가져와 환경 변수로 설정합니다.
try:
    os.environ["KAGGLE_USERNAME"] = userdata.get('KAGGLE_USERNAME')
    os.environ["KAGGLE_KEY"] = userdata.get('KAGGLE_KEY')
except:
    print("User info has not been set")

    # Kaggle 데이터셋 다운로드
print("User info connected successfully!!!")
print("Kaggle credentials loaded successfully. Downloading dataset...")
# !kaggle datasets download -d balraj98/berkeley-segmentation-dataset-500-bsds500

    # 다운로드한 파일 압축 해제
# !unzip -q berkeley-segmentation-dataset-500-bsds500.zip -d ./bsds500

print("Dataset Download and Unzip Complete")
# Out:
# User info connected successfully!!!
# Kaggle credentials loaded successfully. Downloading dataset...
# Dataset URL: https://www.kaggle.com/datasets/balraj98/berkeley-segmentation-dataset-500-bsds500
# License(s): other
# Downloading berkeley-segmentation-dataset-500-bsds500.zip to /content
#   0% 0.00/56.0M [00:00<?, ?B/s]
# 100% 56.0M/56.0M [00:00<00:00, 1.73GB/s]
# Dataset Download and Unzip Complete

# %%
head_path = "/content/bsds500"
ground_truth_path = os.path.join(head_path, "ground_truth")
# 해당 폴더 내의 파일들은 Segmentation 혹은 Edge Detection, Rand Error / Warping Error 평가 시에 사용되는 데이터로,
# 본 파일에서 진행 할 Denoising에서는 사용하지 않는다.

images_path = os.path.join(head_path, "images")
files = os.listdir(head_path)
print(files)
print(os.listdir(ground_truth_path))
print(os.listdir(images_path))

num_test_img = len(os.listdir(os.path.join(images_path, "test")))
num_train_img = len(os.listdir(os.path.join(images_path, "train")))
num_val_img = len(os.listdir(os.path.join(images_path, "val")))

print(f"\nTest 이미지 개수 : {num_test_img}")
print(f"Train 이미지 개수 : {num_train_img}")
print(f"Valid 이미지 개수 : {num_val_img}")
# Out:
# ['ground_truth', 'images']
# ['test', 'val', 'train']
# ['test', 'val', 'train']
#
# Test 이미지 개수 : 201
# Train 이미지 개수 : 201
# Valid 이미지 개수 : 101

# %%
train_path = os.path.join(images_path, "train")
val_path = os.path.join(images_path, "val")
test_path = os.path.join(images_path, "test")

# %%
image_files = os.listdir(train_path)
image_files = [f for f in image_files if f.lower().endswith(".jpg")]

first_image_filename = image_files[0]
first_image_path = os.path.join(train_path, first_image_filename)

plt.imshow(Image.open(first_image_path))
print({Image.open(first_image_path).size}, {Image.open(first_image_path).mode})
plt.show()
# Out:
# {(481, 321)} {'RGB'}

# %%
train_transform = transforms.Compose([
       transforms.RandomChoice([
           transforms.RandomRotation((0, 0)),
           transforms.RandomRotation((90, 90)),
           transforms.RandomRotation((180, 180)),
           transforms.RandomRotation((270, 270))
      ]),
      transforms.RandomCrop(40),
      transforms.RandomVerticalFlip(p=0.5),
      transforms.RandomHorizontalFlip(p=0.5),

      transforms.ToTensor()
])

val_transform = transforms.Compose([
      transforms.CenterCrop(40),
      transforms.ToTensor()
])

# %%
# class CustomDataset(Dataset):
#     def __init__(self, image_path, mode, noise_factor, transform=None):
#         self.image_path = image_path
#         self.mode = mode
#         self.noise_factor = noise_factor
#         self.transform = transform

#         self.image_files = sorted(os.listdir(self.image_path))
#         self.image_files = [f for f in self.image_files if f.lower().endswith(".jpg")]

#     def __len__(self):
#         return len(self.image_files)

#     def __getitem__(self, idx):
#         clean_image = Image.open(os.path.join(self.image_path, self.image_files[idx])).convert("RGB")

#         if self.transform:
#             clean_image = self.transform(clean_image)

#             sigma = self.noise_factor / 255.0
#             noise = torch.randn_like(clean_image) * sigma
#             noisy_image = clean_image + noise
#             noisy_image = torch.clamp(noisy_image, 0.0, 1.0)

#         return noisy_image, clean_image

# %% [markdown]
# ## 랜덤 노이즈 전용 CustomDataset

# %%
import random
class CustomDataset(Dataset):
    def __init__(self, image_path, mode, transform=None):
        self.image_path = image_path
        self.mode = mode
        #self.noise_factor = noise_factor
        self.transform = transform

        self.image_files = sorted(os.listdir(self.image_path))
        self.image_files = [f for f in self.image_files if f.lower().endswith(".jpg")]

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        clean_image = Image.open(os.path.join(self.image_path, self.image_files[idx])).convert("RGB")

        if self.transform:
            clean_image = self.transform(clean_image)

        random_noise = random.uniform(5, 50)
        sigma = random_noise / 255.0

        noise_choice = random.random()
        noisy_image = clean_image.clone()

        if noise_choice < 0.33:
            # Gaussian Noise
            noise = torch.randn_like(clean_image) * sigma
            noisy_image = clean_image + noise
            noise_type = 'Gaussian'

        elif 0.33 <= noise_choice < 0.66:
            # Poisson Noise
            scale = 1.0 / (sigma+1e-6)
            noisy_image = torch.poisson(clean_image*scale) / scale
            noise_type = 'Poisson'

        else:
            noise = torch.randn_like(clean_image) * sigma
            noisy_image = clean_image + (clean_image * noise)
            noise_type = "Speckle"

        noisy_image = torch.clamp(noisy_image, 0.0, 1.0)

        return noisy_image, clean_image, noise_type

# %%
# train_dataset = CustomDataset(train_path, mode='train', noise_factor=50, transform = train_transform)
# val_dataset = CustomDataset(val_path, mode='val', noise_factor=50, transform=val_transform)
# test_dataset = CustomDataset(test_path, mode='test', noise_factor=50, transform=val_transform)

# %%
train_dataset = CustomDataset(train_path, mode='train', transform = train_transform)
val_dataset = CustomDataset(val_path, mode='val', transform=val_transform)
test_dataset = CustomDataset(test_path, mode='test', transform=val_transform)

# %%
train_loader = DataLoader(batch_size=32, shuffle=True, dataset=train_dataset, num_workers=2)
val_loader = DataLoader(batch_size=32, shuffle=False, dataset=val_dataset, num_workers=0)
test_loader = DataLoader(batch_size=32, shuffle=False, dataset=test_dataset, num_workers=0)

# %%
# Noise distribution of each batch.
from collections import Counter

dataiter = iter(train_loader)
_, _, noise_types = next(dataiter)

print(Counter(noise_types))
# Out:
# Counter({'Gaussian': 13, 'Speckle': 11, 'Poisson': 8})

# %%
dataiter = iter(train_loader)
noisy_image, clean_image, noise_types = next(dataiter)

print("Min/Max of Clean:", clean_image.min().item(), clean_image.max().item())
print(noise_types)

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title("Noisy Patch")
plt.imshow(noisy_image[0].permute(1, 2, 0).cpu().numpy())
plt.subplot(1, 2, 2)
plt.title("Clean Patch")
plt.imshow(clean_image[0].permute(1, 2, 0).cpu().numpy())
plt.show()
# Out:
# Min/Max of Clean: 0.0 1.0
# ('Poisson', 'Speckle', 'Gaussian', 'Poisson', 'Gaussian', 'Speckle', 'Poisson', 'Gaussian', 'Poisson', 'Poisson', 'Gaussian', 'Poisson', 'Gaussian', 'Poisson', 'Poisson', 'Poisson', 'Poisson', 'Gaussian', 'Speckle', 'Gaussian', 'Poisson', 'Gaussian', 'Poisson', 'Gaussian', 'Gaussian', 'Poisson', 'Speckle', 'Gaussian', 'Poisson', 'Speckle', 'Gaussian', 'Poisson')

# %%
def analyze(dataset, index=0):
    noisy_tensor, clean_tensor, noise_types = dataset[index]

    noise_only_tensor = noisy_tensor - clean_tensor

    noise_flat = noise_only_tensor.flatten().numpy()
    clean_flat = clean_tensor.flatten().numpy()
    noisy_flat = noisy_tensor.flatten().numpy()

    plt.figure(figsize=(12, 10))

    plt.subplot(231)
    plt.imshow(clean_tensor.permute(1, 2, 0))
    plt.title("Clean Image")

    plt.subplot(232)
    plt.imshow(noisy_tensor.permute(1, 2, 0))
    plt.title("Noisy Image")

    plt.subplot(233)
    #plt.imshow(noise_only_tensor.permute(1, 2, 0))
    vis_noise = noise_only_tensor.permute(1, 2, 0).numpy()
    vis_noise = (vis_noise - np.min(vis_noise)) / (np.max(vis_noise) - np.min(vis_noise))
    plt.imshow(vis_noise)
    plt.title("Noise Only")

    plt.subplot(234)
    plt.hist(clean_flat, bins=100, color='green')
    plt.title("CLean Image")
    plt.xlim(0, 1)

    plt.subplot(235)
    plt.hist(noisy_flat, bins=100, color='red')
    plt.title("Noisy Image")
    plt.xlim(0, 1)

    plt.subplot(236)
    plt.hist(noise_flat, bins=100, color='blue')
    plt.title("Noise Only")
    #sigma_scale = dataset.noise_factor / 255.0
    #plt.xlim(-3 * sigma_scale, 3 * sigma_scale)
    plt.xlim(-0.5, 0.5)
    plt.axvline(0, color='k', linestyle='dashed', linewidth=3)

    plt.show()
analyze(train_dataset, 0)

# %%
class CDnCNN(nn.Module):  # DnCNN of colored image
    def __init__(self, n_channels=3, depth=17):
        super().__init__()

        # Stem
        self.layer1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=64, kernel_size=3, padding=1, bias=True),
            nn.ReLU(inplace=True)
        )

        # Body
        layers=[]
        for _ in range(depth - 2):
            layers.append(nn.Conv2d(64, 64, kernel_size=3, padding=1, bias=False))
            layers.append(nn.BatchNorm2d(64))
            layers.append(nn.ReLU(inplace=True))
        self.body = nn.Sequential(*layers)

        # Head
        self.layer2 = nn.Sequential(
            nn.Conv2d(in_channels=64, out_channels=3, kernel_size=3, padding=1, bias=True),
        )

    def forward(self, x):
        out = self.layer1(x)
        out = self.body(out)
        pred_noise = self.layer2(out)

        return pred_noise

# %%
# def weights_init_kaiming(m):

# %% [markdown]
# ## Loss Function Changed
# - In the case ofo blindn noise, L1 Loss might be better to preserve edge in complicaate noise situation rather than MSE(L2) Loss which square the gap of pixel value.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = CDnCNN().to(device)

n_epochs = 500

optimizer = optim.Adam(model.parameters(), lr = 0.001)
#criterion = nn.MSELoss(reduction='mean')
criterion = nn.L1Loss(reduction='mean')

# %%
INF = 1000
def calculate_PSNR(image1, image2):
    mse = torch.mean((image1 - image2) ** 2)
    if mse == 0:
        return INF
    else:
        return 10 * torch.log10(1.0/mse)

# %%
def train_model(model, train_loader, optimizer, criterion, device, epoch):
    model.train()

    loss_repo = 0.0
    psnr_repo = 0.0

    for inputs, targets, _ in train_loader:
        inputs, targets = inputs.to(device), targets.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        #loss = criterion(outputs, targets)
        noise = inputs - targets
        loss = criterion(outputs, noise)
        denoised = inputs - outputs


        loss.backward()
        optimizer.step()

        denoised_img = inputs - outputs
        loss_repo += loss.item()
        psnr_repo += calculate_PSNR(denoised_img, targets).item()

    epoch_loss = loss_repo / len(train_loader)
    epoch_psnr = psnr_repo / len(train_loader)
    print(f"\nEpoch {epoch} Train - Loss : {epoch_loss:.6f}, PSNR : {epoch_psnr:.2f} dB")
    return epoch_loss, epoch_psnr

# %%
def val_model(model, val_loader, criterion, device, epoch):
    model.eval()

    loss_repo_val = 0.0
    psnr_repo_val = 0.0

    with torch.no_grad():
        for inputs, targets, _ in val_loader:
            inputs, targets = inputs.to(device), targets.to(device)

            outputs = model(inputs)

            noise = inputs - targets
            loss = criterion(outputs, noise)
            #loss = criterion(outputs, targets)


            denoised_img = inputs - outputs
            loss_repo_val += loss.item()
            psnr_repo_val += calculate_PSNR(denoised_img, targets).item()
    val_avg_loss = loss_repo_val / len(val_loader)
    val_avg_psnr = psnr_repo_val / len(val_loader)

    print(f"Epoch {epoch} Valid - Loss : {val_avg_loss:.6f}, PSNR : {val_avg_psnr:2f} dB")
    return val_avg_loss, val_avg_psnr

# %%
def test_model(model, test_loader, criterion, deveice, epoch):
    model.eval()

    test_loss = 0.0
    test_psnr = 0.0

    with torch.no_grad():
        for inputs, targets, _ in test_loader:
            inputs, targets = inputs.to(device), targets.to(device)

            outputs = model(inputs)

            noise = inputs - targets
            loss = criterion(outputs, noise)
            #loss = criterion(outputs, targets)
            denoised_img = inputs - outputs

            test_loss+=loss.item()
            test_psnr+=calculate_PSNR(denoised_img, targets).item()

    avg_loss = test_loss / len(test_loader)
    avg_psnr = test_psnr / len(test_loader)

    print(f"Epoch {epoch} Test - Loss : {avg_loss:.6f}, PSNR : {avg_psnr:.2f} dB")
    return avg_loss, avg_psnr

# %%
best_psnr = 0.0
best_model_wts = None

train_loss = []
train_psnr = []
val_psnr_hist = []

for epoch in range(n_epochs):
    loss, psnr = train_model(model, train_loader, optimizer, criterion, device, epoch+1)
    train_loss.append(loss)
    train_psnr.append(psnr)

    val_loss_epoch, val_psnr_epoch = val_model(model, val_loader, criterion, device, epoch+1)
    val_psnr_hist.append(val_psnr_epoch)

    if val_psnr_epoch > best_psnr:
        best_psnr = val_psnr_epoch
        best_model_wts = model.state_dict()

    current_lr = optimizer.param_groups[0]['lr']
    print(f"Current Learning Rate : {current_lr}")
model.load_state_dict(best_model_wts)
# Out:
# Epoch 1 Train - Loss : 0.177066, PSNR : 11.47 dB
# Epoch 1 Valid - Loss : 0.116962, PSNR : 16.091291 dB
# Current Learning Rate : 0.001
#
# Epoch 2 Train - Loss : 0.081883, PSNR : 17.65 dB
# Epoch 2 Valid - Loss : 0.090256, PSNR : 17.540334 dB
# Current Learning Rate : 0.001
#
# Epoch 3 Train - Loss : 0.085490, PSNR : 17.59 dB
# Epoch 3 Valid - Loss : 0.083926, PSNR : 18.335108 dB
# Current Learning Rate : 0.001
#
# Epoch 4 Train - Loss : 0.085190, PSNR : 17.61 dB
# Epoch 4 Valid - Loss : 0.112825, PSNR : 14.389531 dB
# Current Learning Rate : 0.001
#
# Epoch 5 Train - Loss : 0.076497, PSNR : 18.20 dB
# Epoch 5 Valid - Loss : 0.106215, PSNR : 15.069944 dB
# Current Learning Rate : 0.001
#
# Epoch 6 Train - Loss : 0.080357, PSNR : 17.92 dB
# Epoch 6 Valid - Loss : 0.106362, PSNR : 16.211674 dB
# Current Learning Rate : 0.001
#
# Epoch 7 Train - Loss : 0.077848, PSNR : 18.27 dB
# Epoch 7 Valid - Loss : 0.087370, PSNR : 17.035827 dB
# Current Learning Rate : 0.001
#
# Epoch 8 Train - Loss : 0.076823, PSNR : 18.43 dB
# Epoch 8 Valid - Loss : 0.108307, PSNR : 15.719210 dB
# Current Learning Rate : 0.001
#
# Epoch 9 Train - Loss : 0.077567, PSNR : 18.23 dB
# Epoch 9 Valid - Loss : 0.149200, PSNR : 11.569598 dB
# Current Learning Rate : 0.001
#
# Epoch 10 Train - Loss : 0.079938, PSNR : 18.36 dB
# Epoch 10 Valid - Loss : 0.102443, PSNR : 16.029872 dB
# Current Learning Rate : 0.001
#
# Epoch 11 Train - Loss : 0.080289, PSNR : 17.91 dB
# Epoch 11 Valid - Loss : 0.087565, PSNR : 17.421313 dB
# Current Learning Rate : 0.001
#
# Epoch 12 Train - Loss : 0.081357, PSNR : 17.84 dB
# Epoch 12 Valid - Loss : 0.076761, PSNR : 18.712562 dB
# Current Learning Rate : 0.001
#
# Epoch 13 Train - Loss : 0.081860, PSNR : 17.96 dB
# Epoch 13 Valid - Loss : 0.088475, PSNR : 17.770852 dB
# Current Learning Rate : 0.001
#
# Epoch 14 Train - Loss : 0.079838, PSNR : 18.34 dB
# Epoch 14 Valid - Loss : 0.092758, PSNR : 17.013093 dB
# Current Learning Rate : 0.001
#
# Epoch 15 Train - Loss : 0.085430, PSNR : 18.04 dB
# Epoch 15 Valid - Loss : 0.079176, PSNR : 18.812124 dB
# Current Learning Rate : 0.001
#
# Epoch 16 Train - Loss : 0.092316, PSNR : 17.25 dB
# Epoch 16 Valid - Loss : 0.095248, PSNR : 17.131298 dB
# Current Learning Rate : 0.001
#
# Epoch 17 Train - Loss : 0.092547, PSNR : 17.34 dB
# Epoch 17 Valid - Loss : 0.083894, PSNR : 18.155978 dB
# Current Learning Rate : 0.001
#
# Epoch 18 Train - Loss : 0.084937, PSNR : 17.16 dB
# Epoch 18 Valid - Loss : 0.094000, PSNR : 17.306559 dB
# Current Learning Rate : 0.001
#
# Epoch 19 Train - Loss : 0.088378, PSNR : 17.09 dB
# Epoch 19 Valid - Loss : 0.120726, PSNR : 13.133090 dB
# Current Learning Rate : 0.001
#
# Epoch 20 Train - Loss : 0.084523, PSNR : 17.41 dB
# Epoch 20 Valid - Loss : 0.223641, PSNR : 4.653408 dB
# Current Learning Rate : 0.001
#
# Epoch 21 Train - Loss : 0.090195, PSNR : 16.68 dB
# Epoch 21 Valid - Loss : 0.280001, PSNR : 4.003280 dB
# Current Learning Rate : 0.001
#
# Epoch 22 Train - Loss : 0.085740, PSNR : 17.44 dB
# Epoch 22 Valid - Loss : 0.112219, PSNR : 15.706892 dB
# Current Learning Rate : 0.001
#
# Epoch 23 Train - Loss : 0.094023, PSNR : 17.06 dB
# Epoch 23 Valid - Loss : 0.143595, PSNR : 11.725840 dB
# Current Learning Rate : 0.001
#
# Epoch 24 Train - Loss : 0.078441, PSNR : 17.93 dB
# Epoch 24 Valid - Loss : 0.145566, PSNR : 12.977235 dB
# Current Learning Rate : 0.001
#
# Epoch 25 Train - Loss : 0.079640, PSNR : 18.16 dB
# Epoch 25 Valid - Loss : 0.123534, PSNR : 15.187985 dB
# Current Learning Rate : 0.001
#
# Epoch 26 Train - Loss : 0.079561, PSNR : 18.19 dB
# Epoch 26 Valid - Loss : 0.120290, PSNR : 15.961738 dB
# Current Learning Rate : 0.001
#
# Epoch 27 Train - Loss : 0.076913, PSNR : 17.91 dB
# Epoch 27 Valid - Loss : 0.089788, PSNR : 17.528168 dB
# Current Learning Rate : 0.001
#
# Epoch 28 Train - Loss : 0.086962, PSNR : 17.39 dB
# Epoch 28 Valid - Loss : 0.082728, PSNR : 18.286718 dB
# Current Learning Rate : 0.001
#
# Epoch 29 Train - Loss : 0.079194, PSNR : 18.16 dB
# Epoch 29 Valid - Loss : 0.104710, PSNR : 16.223914 dB
# Current Learning Rate : 0.001
#
# Epoch 30 Train - Loss : 0.072963, PSNR : 18.85 dB
# Epoch 30 Valid - Loss : 0.099981, PSNR : 15.274123 dB
# Current Learning Rate : 0.001
#
# Epoch 31 Train - Loss : 0.079155, PSNR : 18.05 dB
# Epoch 31 Valid - Loss : 0.095466, PSNR : 16.355820 dB
# Current Learning Rate : 0.001
#
# Epoch 32 Train - Loss : 0.077720, PSNR : 18.62 dB
# Epoch 32 Valid - Loss : 0.084534, PSNR : 18.011370 dB
# Current Learning Rate : 0.001
#
# Epoch 33 Train - Loss : 0.081744, PSNR : 17.85 dB
# Epoch 33 Valid - Loss : 0.099417, PSNR : 16.358021 dB
# Current Learning Rate : 0.001
#
# Epoch 34 Train - Loss : 0.081076, PSNR : 17.76 dB
# Epoch 34 Valid - Loss : 0.110965, PSNR : 15.867258 dB
# Current Learning Rate : 0.001
#
# Epoch 35 Train - Loss : 0.083042, PSNR : 17.99 dB
# Epoch 35 Valid - Loss : 0.101543, PSNR : 16.685890 dB
# Current Learning Rate : 0.001
#
# Epoch 36 Train - Loss : 0.075184, PSNR : 18.53 dB
# Epoch 36 Valid - Loss : 0.079163, PSNR : 18.972095 dB
# Current Learning Rate : 0.001
#
# Epoch 37 Train - Loss : 0.082753, PSNR : 17.77 dB
# Epoch 37 Valid - Loss : 0.092468, PSNR : 17.259296 dB
# Current Learning Rate : 0.001
#
# Epoch 38 Train - Loss : 0.077496, PSNR : 18.33 dB
# Epoch 38 Valid - Loss : 0.093992, PSNR : 17.363341 dB
# Current Learning Rate : 0.001
#
# Epoch 39 Train - Loss : 0.083734, PSNR : 17.97 dB
# Epoch 39 Valid - Loss : 0.097492, PSNR : 17.041640 dB
# Current Learning Rate : 0.001
#
# Epoch 40 Train - Loss : 0.090250, PSNR : 17.18 dB
# Epoch 40 Valid - Loss : 0.108855, PSNR : 16.527867 dB
# Current Learning Rate : 0.001
#
# Epoch 41 Train - Loss : 0.085971, PSNR : 17.49 dB
# Epoch 41 Valid - Loss : 0.093054, PSNR : 17.419332 dB
# Current Learning Rate : 0.001
#
# Epoch 42 Train - Loss : 0.081168, PSNR : 17.99 dB
# Epoch 42 Valid - Loss : 0.101893, PSNR : 16.986044 dB
# Current Learning Rate : 0.001
#
# Epoch 43 Train - Loss : 0.066949, PSNR : 19.47 dB
# Epoch 43 Valid - Loss : 0.094474, PSNR : 17.245238 dB
# Current Learning Rate : 0.001
#
# Epoch 44 Train - Loss : 0.071823, PSNR : 18.89 dB
# Epoch 44 Valid - Loss : 0.105727, PSNR : 16.434632 dB
# Current Learning Rate : 0.001
#
# Epoch 45 Train - Loss : 0.072418, PSNR : 18.86 dB
# Epoch 45 Valid - Loss : 0.096950, PSNR : 16.271026 dB
# Current Learning Rate : 0.001
#
# Epoch 46 Train - Loss : 0.079800, PSNR : 17.94 dB
# Epoch 46 Valid - Loss : 0.096250, PSNR : 17.182220 dB
# Current Learning Rate : 0.001
#
# Epoch 47 Train - Loss : 0.076894, PSNR : 18.22 dB
# Epoch 47 Valid - Loss : 0.088821, PSNR : 17.589653 dB
# Current Learning Rate : 0.001
#
# Epoch 48 Train - Loss : 0.077307, PSNR : 18.21 dB
# Epoch 48 Valid - Loss : 0.083576, PSNR : 18.339423 dB
# Current Learning Rate : 0.001
#
# Epoch 49 Train - Loss : 0.077923, PSNR : 18.21 dB
# Epoch 49 Valid - Loss : 0.088633, PSNR : 17.695503 dB
# Current Learning Rate : 0.001
#
# Epoch 50 Train - Loss : 0.077639, PSNR : 18.28 dB
# Epoch 50 Valid - Loss : 0.081970, PSNR : 18.327235 dB
# Current Learning Rate : 0.001
#
# Epoch 51 Train - Loss : 0.086619, PSNR : 17.22 dB
# Epoch 51 Valid - Loss : 0.086812, PSNR : 17.912117 dB
# Current Learning Rate : 0.001
#
# Epoch 52 Train - Loss : 0.077534, PSNR : 18.09 dB
# Epoch 52 Valid - Loss : 0.112012, PSNR : 16.205680 dB
# Current Learning Rate : 0.001
#
# Epoch 53 Train - Loss : 0.077047, PSNR : 18.18 dB
# Epoch 53 Valid - Loss : 0.098322, PSNR : 16.740819 dB
# Current Learning Rate : 0.001
#
# Epoch 54 Train - Loss : 0.071542, PSNR : 18.50 dB
# Epoch 54 Valid - Loss : 0.096140, PSNR : 16.454206 dB
# Current Learning Rate : 0.001
#
# Epoch 55 Train - Loss : 0.080335, PSNR : 17.79 dB
# Epoch 55 Valid - Loss : 0.098602, PSNR : 16.706741 dB
# Current Learning Rate : 0.001
#
# Epoch 56 Train - Loss : 0.077904, PSNR : 18.28 dB
# Epoch 56 Valid - Loss : 0.094185, PSNR : 17.241256 dB
# Current Learning Rate : 0.001
#
# Epoch 57 Train - Loss : 0.082823, PSNR : 17.56 dB
# Epoch 57 Valid - Loss : 0.102774, PSNR : 16.537854 dB
# Current Learning Rate : 0.001
#
# Epoch 58 Train - Loss : 0.080015, PSNR : 17.96 dB
# Epoch 58 Valid - Loss : 0.078451, PSNR : 18.432152 dB
# Current Learning Rate : 0.001
#
# Epoch 59 Train - Loss : 0.083598, PSNR : 17.79 dB
# Epoch 59 Valid - Loss : 0.094484, PSNR : 17.136266 dB
# Current Learning Rate : 0.001
#
# Epoch 60 Train - Loss : 0.073443, PSNR : 18.46 dB
# Epoch 60 Valid - Loss : 0.143538, PSNR : 11.605721 dB
# Current Learning Rate : 0.001
#
# Epoch 61 Train - Loss : 0.083260, PSNR : 17.77 dB
# Epoch 61 Valid - Loss : 0.096402, PSNR : 17.100302 dB
# Current Learning Rate : 0.001
#
# Epoch 62 Train - Loss : 0.079467, PSNR : 18.05 dB
# Epoch 62 Valid - Loss : 0.095674, PSNR : 17.112093 dB
# Current Learning Rate : 0.001
#
# Epoch 63 Train - Loss : 0.074255, PSNR : 18.56 dB
# Epoch 63 Valid - Loss : 0.177592, PSNR : 6.734963 dB
# Current Learning Rate : 0.001
#
# Epoch 64 Train - Loss : 0.079853, PSNR : 17.89 dB
# Epoch 64 Valid - Loss : 0.136706, PSNR : 9.881085 dB
# Current Learning Rate : 0.001
#
# Epoch 65 Train - Loss : 0.084726, PSNR : 17.54 dB
# Epoch 65 Valid - Loss : 0.097613, PSNR : 15.410643 dB
# Current Learning Rate : 0.001
#
# Epoch 66 Train - Loss : 0.069416, PSNR : 19.29 dB
# Epoch 66 Valid - Loss : 0.097546, PSNR : 17.062556 dB
# Current Learning Rate : 0.001
#
# Epoch 67 Train - Loss : 0.079891, PSNR : 18.12 dB
# Epoch 67 Valid - Loss : 0.094976, PSNR : 17.294382 dB
# Current Learning Rate : 0.001
#
# Epoch 68 Train - Loss : 0.074614, PSNR : 18.08 dB
# Epoch 68 Valid - Loss : 0.097085, PSNR : 15.913088 dB
# Current Learning Rate : 0.001
#
# Epoch 69 Train - Loss : 0.084154, PSNR : 17.70 dB
# Epoch 69 Valid - Loss : 0.101519, PSNR : 16.572982 dB
# Current Learning Rate : 0.001
#
# Epoch 70 Train - Loss : 0.079057, PSNR : 18.04 dB
# Epoch 70 Valid - Loss : 0.089521, PSNR : 17.697084 dB
# Current Learning Rate : 0.001
#
# Epoch 71 Train - Loss : 0.078751, PSNR : 17.96 dB
# Epoch 71 Valid - Loss : 0.100078, PSNR : 16.378927 dB
# Current Learning Rate : 0.001
#
# Epoch 72 Train - Loss : 0.081568, PSNR : 17.77 dB
# Epoch 72 Valid - Loss : 0.141290, PSNR : 8.794899 dB
# Current Learning Rate : 0.001
#
# Epoch 73 Train - Loss : 0.081504, PSNR : 17.71 dB
# Epoch 73 Valid - Loss : 0.075229, PSNR : 19.665195 dB
# Current Learning Rate : 0.001
#
# Epoch 74 Train - Loss : 0.082270, PSNR : 17.78 dB
# Epoch 74 Valid - Loss : 0.084989, PSNR : 17.554729 dB
# Current Learning Rate : 0.001
#
# Epoch 75 Train - Loss : 0.074827, PSNR : 18.29 dB
# Epoch 75 Valid - Loss : 0.120423, PSNR : 14.323285 dB
# Current Learning Rate : 0.001
#
# Epoch 76 Train - Loss : 0.070702, PSNR : 18.79 dB
# Epoch 76 Valid - Loss : 0.107994, PSNR : 16.303728 dB
# Current Learning Rate : 0.001
#
# Epoch 77 Train - Loss : 0.074480, PSNR : 18.38 dB
# Epoch 77 Valid - Loss : 0.130600, PSNR : 12.377068 dB
# Current Learning Rate : 0.001
#
# Epoch 78 Train - Loss : 0.079677, PSNR : 18.04 dB
# Epoch 78 Valid - Loss : 0.089640, PSNR : 17.620886 dB
# Current Learning Rate : 0.001
#
# Epoch 79 Train - Loss : 0.068167, PSNR : 19.12 dB
# Epoch 79 Valid - Loss : 0.096313, PSNR : 17.210022 dB
# Current Learning Rate : 0.001
#
# Epoch 80 Train - Loss : 0.076346, PSNR : 18.17 dB
# Epoch 80 Valid - Loss : 0.116076, PSNR : 15.744648 dB
# Current Learning Rate : 0.001
#
# Epoch 81 Train - Loss : 0.077546, PSNR : 18.26 dB
# Epoch 81 Valid - Loss : 0.108465, PSNR : 16.581535 dB
# Current Learning Rate : 0.001
#
# Epoch 82 Train - Loss : 0.082820, PSNR : 17.69 dB
# Epoch 82 Valid - Loss : 0.117624, PSNR : 13.347987 dB
# Current Learning Rate : 0.001
#
# Epoch 83 Train - Loss : 0.082433, PSNR : 17.71 dB
# Epoch 83 Valid - Loss : 0.095091, PSNR : 16.841442 dB
# Current Learning Rate : 0.001
#
# Epoch 84 Train - Loss : 0.073273, PSNR : 18.78 dB
# Epoch 84 Valid - Loss : 0.122885, PSNR : 12.167977 dB
# Current Learning Rate : 0.001
#
# Epoch 85 Train - Loss : 0.082293, PSNR : 17.79 dB
# Epoch 85 Valid - Loss : 0.090504, PSNR : 17.505570 dB
# Current Learning Rate : 0.001
#
# Epoch 86 Train - Loss : 0.084844, PSNR : 17.70 dB
# Epoch 86 Valid - Loss : 0.096904, PSNR : 17.008468 dB
# Current Learning Rate : 0.001
#
# Epoch 87 Train - Loss : 0.086419, PSNR : 17.42 dB
# Epoch 87 Valid - Loss : 0.093578, PSNR : 17.365814 dB
# Current Learning Rate : 0.001
#
# Epoch 88 Train - Loss : 0.081096, PSNR : 17.85 dB
# Epoch 88 Valid - Loss : 0.500016, PSNR : -1.209362 dB
# Current Learning Rate : 0.001
#
# Epoch 89 Train - Loss : 0.076222, PSNR : 18.26 dB
# Epoch 89 Valid - Loss : 0.326806, PSNR : 4.399050 dB
# Current Learning Rate : 0.001
#
# Epoch 90 Train - Loss : 0.077550, PSNR : 18.23 dB
# Epoch 90 Valid - Loss : 0.255392, PSNR : 6.473347 dB
# Current Learning Rate : 0.001
#
# Epoch 91 Train - Loss : 0.077530, PSNR : 18.57 dB
# Epoch 91 Valid - Loss : 0.117442, PSNR : 14.923400 dB
# Current Learning Rate : 0.001
#
# Epoch 92 Train - Loss : 0.080419, PSNR : 18.00 dB
# Epoch 92 Valid - Loss : 0.104969, PSNR : 16.344332 dB
# Current Learning Rate : 0.001
#
# Epoch 93 Train - Loss : 0.079616, PSNR : 17.86 dB
# Epoch 93 Valid - Loss : 0.087557, PSNR : 17.901886 dB
# Current Learning Rate : 0.001
#
# Epoch 94 Train - Loss : 0.082793, PSNR : 17.84 dB
# Epoch 94 Valid - Loss : 0.080838, PSNR : 18.391876 dB
# Current Learning Rate : 0.001
#
# Epoch 95 Train - Loss : 0.074242, PSNR : 18.36 dB
# Epoch 95 Valid - Loss : 0.081038, PSNR : 18.251571 dB
# Current Learning Rate : 0.001
#
# Epoch 96 Train - Loss : 0.074139, PSNR : 18.46 dB
# Epoch 96 Valid - Loss : 0.090608, PSNR : 17.300845 dB
# Current Learning Rate : 0.001
#
# Epoch 97 Train - Loss : 0.073564, PSNR : 18.81 dB
# Epoch 97 Valid - Loss : 0.099790, PSNR : 16.834168 dB
# Current Learning Rate : 0.001
#
# Epoch 98 Train - Loss : 0.068041, PSNR : 19.26 dB
# Epoch 98 Valid - Loss : 0.090421, PSNR : 17.490870 dB
# Current Learning Rate : 0.001
#
# Epoch 99 Train - Loss : 0.072191, PSNR : 18.73 dB
# Epoch 99 Valid - Loss : 0.092121, PSNR : 17.463493 dB
# Current Learning Rate : 0.001
#
# Epoch 100 Train - Loss : 0.080269, PSNR : 17.93 dB
# Epoch 100 Valid - Loss : 0.094683, PSNR : 17.346234 dB
# Current Learning Rate : 0.001
#
# Epoch 101 Train - Loss : 0.075234, PSNR : 18.71 dB
# Epoch 101 Valid - Loss : 0.088932, PSNR : 17.891836 dB
# Current Learning Rate : 0.001
#
# Epoch 102 Train - Loss : 0.071820, PSNR : 18.77 dB
# Epoch 102 Valid - Loss : 0.091855, PSNR : 17.275372 dB
# Current Learning Rate : 0.001
#
# Epoch 103 Train - Loss : 0.073559, PSNR : 18.66 dB
# Epoch 103 Valid - Loss : 0.093157, PSNR : 17.104023 dB
# Current Learning Rate : 0.001
#
# Epoch 104 Train - Loss : 0.069528, PSNR : 18.83 dB
# Epoch 104 Valid - Loss : 0.096984, PSNR : 16.946562 dB
# Current Learning Rate : 0.001
#
# Epoch 105 Train - Loss : 0.076883, PSNR : 18.23 dB
# Epoch 105 Valid - Loss : 0.090936, PSNR : 17.483339 dB
# Current Learning Rate : 0.001
#
# Epoch 106 Train - Loss : 0.077040, PSNR : 18.23 dB
# Epoch 106 Valid - Loss : 0.087386, PSNR : 17.593580 dB
# Current Learning Rate : 0.001
#
# Epoch 107 Train - Loss : 0.074782, PSNR : 18.29 dB
# Epoch 107 Valid - Loss : 0.094900, PSNR : 17.230771 dB
# Current Learning Rate : 0.001
#
# Epoch 108 Train - Loss : 0.070726, PSNR : 18.55 dB
# Epoch 108 Valid - Loss : 0.086449, PSNR : 17.983739 dB
# Current Learning Rate : 0.001
#
# Epoch 109 Train - Loss : 0.078486, PSNR : 18.14 dB
# Epoch 109 Valid - Loss : 0.102757, PSNR : 16.290203 dB
# Current Learning Rate : 0.001
#
# Epoch 110 Train - Loss : 0.068865, PSNR : 18.81 dB
# Epoch 110 Valid - Loss : 0.095175, PSNR : 17.133857 dB
# Current Learning Rate : 0.001
#
# Epoch 111 Train - Loss : 0.080196, PSNR : 18.08 dB
# Epoch 111 Valid - Loss : 0.099582, PSNR : 17.015017 dB
# Current Learning Rate : 0.001
#
# Epoch 112 Train - Loss : 0.069177, PSNR : 18.93 dB
# Epoch 112 Valid - Loss : 0.080297, PSNR : 18.607609 dB
# Current Learning Rate : 0.001
#
# Epoch 113 Train - Loss : 0.077206, PSNR : 18.14 dB
# Epoch 113 Valid - Loss : 0.097078, PSNR : 16.958044 dB
# Current Learning Rate : 0.001
#
# Epoch 114 Train - Loss : 0.079299, PSNR : 18.04 dB
# Epoch 114 Valid - Loss : 0.085858, PSNR : 18.060436 dB
# Current Learning Rate : 0.001
#
# Epoch 115 Train - Loss : 0.079697, PSNR : 17.94 dB
# Epoch 115 Valid - Loss : 0.097479, PSNR : 16.826489 dB
# Current Learning Rate : 0.001
#
# Epoch 116 Train - Loss : 0.071067, PSNR : 18.82 dB
# Epoch 116 Valid - Loss : 0.095166, PSNR : 17.200324 dB
# Current Learning Rate : 0.001
#
# Epoch 117 Train - Loss : 0.074895, PSNR : 18.46 dB
# Epoch 117 Valid - Loss : 0.096283, PSNR : 16.921449 dB
# Current Learning Rate : 0.001
#
# Epoch 118 Train - Loss : 0.070473, PSNR : 18.91 dB
# Epoch 118 Valid - Loss : 0.094512, PSNR : 16.957895 dB
# Current Learning Rate : 0.001
#
# Epoch 119 Train - Loss : 0.079672, PSNR : 18.11 dB
# Epoch 119 Valid - Loss : 0.094058, PSNR : 17.400363 dB
# Current Learning Rate : 0.001
#
# Epoch 120 Train - Loss : 0.074137, PSNR : 18.56 dB
# Epoch 120 Valid - Loss : 0.088642, PSNR : 17.889561 dB
# Current Learning Rate : 0.001
#
# Epoch 121 Train - Loss : 0.081011, PSNR : 17.90 dB
# Epoch 121 Valid - Loss : 0.095023, PSNR : 17.081606 dB
# Current Learning Rate : 0.001
#
# Epoch 122 Train - Loss : 0.072449, PSNR : 18.40 dB
# Epoch 122 Valid - Loss : 0.079746, PSNR : 18.405749 dB
# Current Learning Rate : 0.001
#
# Epoch 123 Train - Loss : 0.074644, PSNR : 18.52 dB
# Epoch 123 Valid - Loss : 0.080753, PSNR : 18.328443 dB
# Current Learning Rate : 0.001
#
# Epoch 124 Train - Loss : 0.077950, PSNR : 18.12 dB
# Epoch 124 Valid - Loss : 0.078761, PSNR : 18.597903 dB
# Current Learning Rate : 0.001
#
# Epoch 125 Train - Loss : 0.075088, PSNR : 18.45 dB
# Epoch 125 Valid - Loss : 0.101630, PSNR : 16.788757 dB
# Current Learning Rate : 0.001
#
# Epoch 126 Train - Loss : 0.083327, PSNR : 17.74 dB
# Epoch 126 Valid - Loss : 0.094654, PSNR : 16.789955 dB
# Current Learning Rate : 0.001
#
# Epoch 127 Train - Loss : 0.072894, PSNR : 18.63 dB
# Epoch 127 Valid - Loss : 0.096564, PSNR : 16.594752 dB
# Current Learning Rate : 0.001
#
# Epoch 128 Train - Loss : 0.077948, PSNR : 18.34 dB
# Epoch 128 Valid - Loss : 0.085388, PSNR : 17.863878 dB
# Current Learning Rate : 0.001
#
# Epoch 129 Train - Loss : 0.073257, PSNR : 18.52 dB
# Epoch 129 Valid - Loss : 0.086561, PSNR : 17.270132 dB
# Current Learning Rate : 0.001
#
# Epoch 130 Train - Loss : 0.079436, PSNR : 18.00 dB
# Epoch 130 Valid - Loss : 0.087290, PSNR : 16.802552 dB
# Current Learning Rate : 0.001
#
# Epoch 131 Train - Loss : 0.077701, PSNR : 18.27 dB
# Epoch 131 Valid - Loss : 0.098136, PSNR : 14.851468 dB
# Current Learning Rate : 0.001
#
# Epoch 132 Train - Loss : 0.076344, PSNR : 18.00 dB
# Epoch 132 Valid - Loss : 0.102609, PSNR : 13.288970 dB
# Current Learning Rate : 0.001
#
# Epoch 133 Train - Loss : 0.075008, PSNR : 18.55 dB
# Epoch 133 Valid - Loss : 0.085590, PSNR : 17.819615 dB
# Current Learning Rate : 0.001
#
# Epoch 134 Train - Loss : 0.081714, PSNR : 17.66 dB
# Epoch 134 Valid - Loss : 0.090340, PSNR : 17.421356 dB
# Current Learning Rate : 0.001
#
# Epoch 135 Train - Loss : 0.079929, PSNR : 17.93 dB
# Epoch 135 Valid - Loss : 0.075103, PSNR : 19.080859 dB
# Current Learning Rate : 0.001
#
# Epoch 136 Train - Loss : 0.071449, PSNR : 18.75 dB
# Epoch 136 Valid - Loss : 0.085258, PSNR : 17.962243 dB
# Current Learning Rate : 0.001
#
# Epoch 137 Train - Loss : 0.078271, PSNR : 18.29 dB
# Epoch 137 Valid - Loss : 0.079731, PSNR : 18.475705 dB
# Current Learning Rate : 0.001
#
# Epoch 138 Train - Loss : 0.078986, PSNR : 18.12 dB
# Epoch 138 Valid - Loss : 0.083097, PSNR : 18.039545 dB
# Current Learning Rate : 0.001
#
# Epoch 139 Train - Loss : 0.074134, PSNR : 18.45 dB
# Epoch 139 Valid - Loss : 0.083008, PSNR : 17.611307 dB
# Current Learning Rate : 0.001
#
# Epoch 140 Train - Loss : 0.079240, PSNR : 18.20 dB
# Epoch 140 Valid - Loss : 0.088628, PSNR : 17.367612 dB
# Current Learning Rate : 0.001
#
# Epoch 141 Train - Loss : 0.076956, PSNR : 18.16 dB
# Epoch 141 Valid - Loss : 0.082646, PSNR : 18.744612 dB
# Current Learning Rate : 0.001
#
# Epoch 142 Train - Loss : 0.066952, PSNR : 19.13 dB
# Epoch 142 Valid - Loss : 0.102634, PSNR : 16.640946 dB
# Current Learning Rate : 0.001
#
# Epoch 143 Train - Loss : 0.069841, PSNR : 18.80 dB
# Epoch 143 Valid - Loss : 0.094676, PSNR : 17.250341 dB
# Current Learning Rate : 0.001
#
# Epoch 144 Train - Loss : 0.075350, PSNR : 18.36 dB
# Epoch 144 Valid - Loss : 0.083705, PSNR : 17.988705 dB
# Current Learning Rate : 0.001
#
# Epoch 145 Train - Loss : 0.082250, PSNR : 17.99 dB
# Epoch 145 Valid - Loss : 0.085597, PSNR : 17.724746 dB
# Current Learning Rate : 0.001
#
# Epoch 146 Train - Loss : 0.081009, PSNR : 17.92 dB
# Epoch 146 Valid - Loss : 0.078244, PSNR : 19.219210 dB
# Current Learning Rate : 0.001
#
# Epoch 147 Train - Loss : 0.077042, PSNR : 18.27 dB
# Epoch 147 Valid - Loss : 0.088393, PSNR : 17.183945 dB
# Current Learning Rate : 0.001
#
# Epoch 148 Train - Loss : 0.076921, PSNR : 18.26 dB
# Epoch 148 Valid - Loss : 0.090260, PSNR : 17.360963 dB
# Current Learning Rate : 0.001
#
# Epoch 149 Train - Loss : 0.084208, PSNR : 17.90 dB
# Epoch 149 Valid - Loss : 0.093275, PSNR : 17.001969 dB
# Current Learning Rate : 0.001
#
# Epoch 150 Train - Loss : 0.073848, PSNR : 18.53 dB
# Epoch 150 Valid - Loss : 0.110744, PSNR : 14.770836 dB
# Current Learning Rate : 0.001
#
# Epoch 151 Train - Loss : 0.071270, PSNR : 19.03 dB
# Epoch 151 Valid - Loss : 0.127167, PSNR : 13.226303 dB
# Current Learning Rate : 0.001
#
# Epoch 152 Train - Loss : 0.078615, PSNR : 18.39 dB
# Epoch 152 Valid - Loss : 0.178626, PSNR : 9.947481 dB
# Current Learning Rate : 0.001
#
# Epoch 153 Train - Loss : 0.075719, PSNR : 18.26 dB
# Epoch 153 Valid - Loss : 0.091848, PSNR : 17.058674 dB
# Current Learning Rate : 0.001
#
# Epoch 154 Train - Loss : 0.083306, PSNR : 17.78 dB
# Epoch 154 Valid - Loss : 0.095257, PSNR : 17.240467 dB
# Current Learning Rate : 0.001
#
# Epoch 155 Train - Loss : 0.077427, PSNR : 18.18 dB
# Epoch 155 Valid - Loss : 0.108476, PSNR : 15.863304 dB
# Current Learning Rate : 0.001
#
# Epoch 156 Train - Loss : 0.077884, PSNR : 18.17 dB
# Epoch 156 Valid - Loss : 0.082209, PSNR : 18.421539 dB
# Current Learning Rate : 0.001
#
# Epoch 157 Train - Loss : 0.072888, PSNR : 18.63 dB
# Epoch 157 Valid - Loss : 0.096355, PSNR : 16.676814 dB
# Current Learning Rate : 0.001
#
# Epoch 158 Train - Loss : 0.075525, PSNR : 18.49 dB
# Epoch 158 Valid - Loss : 0.079466, PSNR : 18.706127 dB
# Current Learning Rate : 0.001
#
# Epoch 159 Train - Loss : 0.080341, PSNR : 18.16 dB
# Epoch 159 Valid - Loss : 0.090669, PSNR : 17.334858 dB
# Current Learning Rate : 0.001
#
# Epoch 160 Train - Loss : 0.076029, PSNR : 18.38 dB
# Epoch 160 Valid - Loss : 0.079603, PSNR : 18.781023 dB
# Current Learning Rate : 0.001
#
# Epoch 161 Train - Loss : 0.078997, PSNR : 18.06 dB
# Epoch 161 Valid - Loss : 0.095520, PSNR : 16.829004 dB
# Current Learning Rate : 0.001
#
# Epoch 162 Train - Loss : 0.077093, PSNR : 18.37 dB
# Epoch 162 Valid - Loss : 0.066098, PSNR : 20.081244 dB
# Current Learning Rate : 0.001
#
# Epoch 163 Train - Loss : 0.074870, PSNR : 18.48 dB
# Epoch 163 Valid - Loss : 0.100634, PSNR : 16.711721 dB
# Current Learning Rate : 0.001
#
# Epoch 164 Train - Loss : 0.073067, PSNR : 18.94 dB
# Epoch 164 Valid - Loss : 0.100789, PSNR : 16.745957 dB
# Current Learning Rate : 0.001
#
# Epoch 165 Train - Loss : 0.074930, PSNR : 18.34 dB
# Epoch 165 Valid - Loss : 0.100247, PSNR : 16.619916 dB
# Current Learning Rate : 0.001
#
# Epoch 166 Train - Loss : 0.074928, PSNR : 18.45 dB
# Epoch 166 Valid - Loss : 0.081219, PSNR : 17.618773 dB
# Current Learning Rate : 0.001
#
# Epoch 167 Train - Loss : 0.084337, PSNR : 17.67 dB
# Epoch 167 Valid - Loss : 0.082566, PSNR : 18.349914 dB
# Current Learning Rate : 0.001
#
# Epoch 168 Train - Loss : 0.073981, PSNR : 18.42 dB
# Epoch 168 Valid - Loss : 0.091901, PSNR : 17.391541 dB
# Current Learning Rate : 0.001
#
# Epoch 169 Train - Loss : 0.082484, PSNR : 17.87 dB
# Epoch 169 Valid - Loss : 0.074531, PSNR : 18.841347 dB
# Current Learning Rate : 0.001
#
# Epoch 170 Train - Loss : 0.080564, PSNR : 17.99 dB
# Epoch 170 Valid - Loss : 0.088043, PSNR : 17.453574 dB
# Current Learning Rate : 0.001
#
# Epoch 171 Train - Loss : 0.078188, PSNR : 18.20 dB
# Epoch 171 Valid - Loss : 0.078001, PSNR : 18.762757 dB
# Current Learning Rate : 0.001
#
# Epoch 172 Train - Loss : 0.075309, PSNR : 18.50 dB
# Epoch 172 Valid - Loss : 0.097382, PSNR : 17.309655 dB
# Current Learning Rate : 0.001
#
# Epoch 173 Train - Loss : 0.075551, PSNR : 18.59 dB
# Epoch 173 Valid - Loss : 0.080864, PSNR : 18.065624 dB
# Current Learning Rate : 0.001
#
# Epoch 174 Train - Loss : 0.073083, PSNR : 18.56 dB
# Epoch 174 Valid - Loss : 0.093105, PSNR : 16.296796 dB
# Current Learning Rate : 0.001
#
# Epoch 175 Train - Loss : 0.072805, PSNR : 18.63 dB
# Epoch 175 Valid - Loss : 0.106477, PSNR : 15.772852 dB
# Current Learning Rate : 0.001
#
# Epoch 176 Train - Loss : 0.072953, PSNR : 18.73 dB
# Epoch 176 Valid - Loss : 0.128285, PSNR : 12.988527 dB
# Current Learning Rate : 0.001
#
# Epoch 177 Train - Loss : 0.077905, PSNR : 18.13 dB
# Epoch 177 Valid - Loss : 0.105200, PSNR : 15.631541 dB
# Current Learning Rate : 0.001
#
# Epoch 178 Train - Loss : 0.073767, PSNR : 18.51 dB
# Epoch 178 Valid - Loss : 0.107462, PSNR : 15.131395 dB
# Current Learning Rate : 0.001
#
# Epoch 179 Train - Loss : 0.084082, PSNR : 17.87 dB
# Epoch 179 Valid - Loss : 0.091232, PSNR : 17.544696 dB
# Current Learning Rate : 0.001
#
# Epoch 180 Train - Loss : 0.075853, PSNR : 18.43 dB
# Epoch 180 Valid - Loss : 0.109556, PSNR : 16.217252 dB
# Current Learning Rate : 0.001
#
# Epoch 181 Train - Loss : 0.082137, PSNR : 17.83 dB
# Epoch 181 Valid - Loss : 0.099584, PSNR : 16.635247 dB
# Current Learning Rate : 0.001
#
# Epoch 182 Train - Loss : 0.083865, PSNR : 17.66 dB
# Epoch 182 Valid - Loss : 0.090326, PSNR : 17.493553 dB
# Current Learning Rate : 0.001
#
# Epoch 183 Train - Loss : 0.073227, PSNR : 18.45 dB
# Epoch 183 Valid - Loss : 0.089098, PSNR : 17.520324 dB
# Current Learning Rate : 0.001
#
# Epoch 184 Train - Loss : 0.076221, PSNR : 18.44 dB
# Epoch 184 Valid - Loss : 0.093743, PSNR : 16.948931 dB
# Current Learning Rate : 0.001
#
# Epoch 185 Train - Loss : 0.076185, PSNR : 18.32 dB
# Epoch 185 Valid - Loss : 0.089636, PSNR : 17.674681 dB
# Current Learning Rate : 0.001
#
# Epoch 186 Train - Loss : 0.074245, PSNR : 18.46 dB
# Epoch 186 Valid - Loss : 0.090033, PSNR : 17.600590 dB
# Current Learning Rate : 0.001
#
# Epoch 187 Train - Loss : 0.078057, PSNR : 18.19 dB
# Epoch 187 Valid - Loss : 0.097931, PSNR : 16.866135 dB
# Current Learning Rate : 0.001
#
# Epoch 188 Train - Loss : 0.077271, PSNR : 18.21 dB
# Epoch 188 Valid - Loss : 0.101656, PSNR : 15.664335 dB
# Current Learning Rate : 0.001
#
# Epoch 189 Train - Loss : 0.070655, PSNR : 18.96 dB
# Epoch 189 Valid - Loss : 0.096784, PSNR : 16.125484 dB
# Current Learning Rate : 0.001
#
# Epoch 190 Train - Loss : 0.080756, PSNR : 18.05 dB
# Epoch 190 Valid - Loss : 0.085845, PSNR : 17.410816 dB
# Current Learning Rate : 0.001
#
# Epoch 191 Train - Loss : 0.069741, PSNR : 18.90 dB
# Epoch 191 Valid - Loss : 0.091402, PSNR : 17.365174 dB
# Current Learning Rate : 0.001
#
# Epoch 192 Train - Loss : 0.081029, PSNR : 17.91 dB
# Epoch 192 Valid - Loss : 0.082991, PSNR : 17.793769 dB
# Current Learning Rate : 0.001
#
# Epoch 193 Train - Loss : 0.074682, PSNR : 18.45 dB
# Epoch 193 Valid - Loss : 0.080913, PSNR : 18.317634 dB
# Current Learning Rate : 0.001
#
# Epoch 194 Train - Loss : 0.079746, PSNR : 18.16 dB
# Epoch 194 Valid - Loss : 0.063046, PSNR : 21.252616 dB
# Current Learning Rate : 0.001
#
# Epoch 195 Train - Loss : 0.077166, PSNR : 18.19 dB
# Epoch 195 Valid - Loss : 0.087717, PSNR : 17.568965 dB
# Current Learning Rate : 0.001
#
# Epoch 196 Train - Loss : 0.076914, PSNR : 18.27 dB
# Epoch 196 Valid - Loss : 0.083736, PSNR : 18.109153 dB
# Current Learning Rate : 0.001
#
# Epoch 197 Train - Loss : 0.078759, PSNR : 18.12 dB
# Epoch 197 Valid - Loss : 0.094132, PSNR : 16.970486 dB
# Current Learning Rate : 0.001
#
# Epoch 198 Train - Loss : 0.082285, PSNR : 17.95 dB
# Epoch 198 Valid - Loss : 0.091262, PSNR : 17.078194 dB
# Current Learning Rate : 0.001
#
# Epoch 199 Train - Loss : 0.068804, PSNR : 18.87 dB
# Epoch 199 Valid - Loss : 0.095496, PSNR : 16.932149 dB
# Current Learning Rate : 0.001
#
# Epoch 200 Train - Loss : 0.072575, PSNR : 18.77 dB
# Epoch 200 Valid - Loss : 0.076580, PSNR : 19.735424 dB
# Current Learning Rate : 0.001
#
# Epoch 201 Train - Loss : 0.075331, PSNR : 18.56 dB
# Epoch 201 Valid - Loss : 0.105160, PSNR : 16.055002 dB
# Current Learning Rate : 0.001
#
# Epoch 202 Train - Loss : 0.069475, PSNR : 19.11 dB
# Epoch 202 Valid - Loss : 0.077281, PSNR : 18.859340 dB
# Current Learning Rate : 0.001
#
# Epoch 203 Train - Loss : 0.075107, PSNR : 18.38 dB
# Epoch 203 Valid - Loss : 0.099245, PSNR : 16.274879 dB
# Current Learning Rate : 0.001
#
# Epoch 204 Train - Loss : 0.069480, PSNR : 18.71 dB
# Epoch 204 Valid - Loss : 0.103223, PSNR : 15.315479 dB
# Current Learning Rate : 0.001
#
# Epoch 205 Train - Loss : 0.068080, PSNR : 19.32 dB
# Epoch 205 Valid - Loss : 0.097352, PSNR : 16.784445 dB
# Current Learning Rate : 0.001
#
# Epoch 206 Train - Loss : 0.075786, PSNR : 18.18 dB
# Epoch 206 Valid - Loss : 0.087044, PSNR : 17.927423 dB
# Current Learning Rate : 0.001
#
# Epoch 207 Train - Loss : 0.071920, PSNR : 18.69 dB
# Epoch 207 Valid - Loss : 0.076976, PSNR : 18.755175 dB
# Current Learning Rate : 0.001
#
# Epoch 208 Train - Loss : 0.070225, PSNR : 18.79 dB
# Epoch 208 Valid - Loss : 0.097530, PSNR : 17.179886 dB
# Current Learning Rate : 0.001
#
# Epoch 209 Train - Loss : 0.071278, PSNR : 19.10 dB
# Epoch 209 Valid - Loss : 0.092929, PSNR : 17.103477 dB
# Current Learning Rate : 0.001
#
# Epoch 210 Train - Loss : 0.077989, PSNR : 18.30 dB
# Epoch 210 Valid - Loss : 0.074971, PSNR : 18.750737 dB
# Current Learning Rate : 0.001
#
# Epoch 211 Train - Loss : 0.073282, PSNR : 18.60 dB
# Epoch 211 Valid - Loss : 0.088547, PSNR : 17.868513 dB
# Current Learning Rate : 0.001
#
# Epoch 212 Train - Loss : 0.073811, PSNR : 18.59 dB
# Epoch 212 Valid - Loss : 0.089791, PSNR : 17.871305 dB
# Current Learning Rate : 0.001
#
# Epoch 213 Train - Loss : 0.075523, PSNR : 18.46 dB
# Epoch 213 Valid - Loss : 0.084345, PSNR : 17.868957 dB
# Current Learning Rate : 0.001
#
# Epoch 214 Train - Loss : 0.079846, PSNR : 17.84 dB
# Epoch 214 Valid - Loss : 0.087643, PSNR : 17.591832 dB
# Current Learning Rate : 0.001
#
# Epoch 215 Train - Loss : 0.076944, PSNR : 18.50 dB
# Epoch 215 Valid - Loss : 0.096867, PSNR : 16.562384 dB
# Current Learning Rate : 0.001
#
# Epoch 216 Train - Loss : 0.075040, PSNR : 18.53 dB
# Epoch 216 Valid - Loss : 0.091181, PSNR : 17.331225 dB
# Current Learning Rate : 0.001
#
# Epoch 217 Train - Loss : 0.074636, PSNR : 18.31 dB
# Epoch 217 Valid - Loss : 0.098628, PSNR : 16.929004 dB
# Current Learning Rate : 0.001
#
# Epoch 218 Train - Loss : 0.071721, PSNR : 18.92 dB
# Epoch 218 Valid - Loss : 0.108174, PSNR : 15.924749 dB
# Current Learning Rate : 0.001
#
# Epoch 219 Train - Loss : 0.077016, PSNR : 18.21 dB
# Epoch 219 Valid - Loss : 0.469462, PSNR : 1.956933 dB
# Current Learning Rate : 0.001
#
# Epoch 220 Train - Loss : 0.072669, PSNR : 18.78 dB
# Epoch 220 Valid - Loss : 0.087556, PSNR : 16.993910 dB
# Current Learning Rate : 0.001
#
# Epoch 221 Train - Loss : 0.081288, PSNR : 17.97 dB
# Epoch 221 Valid - Loss : 0.092215, PSNR : 17.382028 dB
# Current Learning Rate : 0.001
#
# Epoch 222 Train - Loss : 0.074115, PSNR : 18.57 dB
# Epoch 222 Valid - Loss : 0.084895, PSNR : 17.745795 dB
# Current Learning Rate : 0.001
#
# Epoch 223 Train - Loss : 0.068305, PSNR : 19.32 dB
# Epoch 223 Valid - Loss : 0.087714, PSNR : 17.687246 dB
# Current Learning Rate : 0.001
#
# Epoch 224 Train - Loss : 0.073503, PSNR : 18.51 dB
# Epoch 224 Valid - Loss : 0.091114, PSNR : 17.121827 dB
# Current Learning Rate : 0.001
#
# Epoch 225 Train - Loss : 0.079716, PSNR : 18.11 dB
# Epoch 225 Valid - Loss : 0.100790, PSNR : 17.000158 dB
# Current Learning Rate : 0.001
#
# Epoch 226 Train - Loss : 0.079919, PSNR : 18.13 dB
# Epoch 226 Valid - Loss : 0.091629, PSNR : 17.174619 dB
# Current Learning Rate : 0.001
#
# Epoch 227 Train - Loss : 0.071433, PSNR : 18.70 dB
# Epoch 227 Valid - Loss : 0.159649, PSNR : 9.802508 dB
# Current Learning Rate : 0.001
#
# Epoch 228 Train - Loss : 0.078396, PSNR : 17.97 dB
# Epoch 228 Valid - Loss : 0.086560, PSNR : 17.740799 dB
# Current Learning Rate : 0.001
#
# Epoch 229 Train - Loss : 0.068006, PSNR : 19.29 dB
# Epoch 229 Valid - Loss : 0.101142, PSNR : 16.912940 dB
# Current Learning Rate : 0.001
#
# Epoch 230 Train - Loss : 0.084003, PSNR : 17.65 dB
# Epoch 230 Valid - Loss : 0.133779, PSNR : 14.568626 dB
# Current Learning Rate : 0.001
#
# Epoch 231 Train - Loss : 0.077147, PSNR : 17.94 dB
# Epoch 231 Valid - Loss : 0.244312, PSNR : 6.718976 dB
# Current Learning Rate : 0.001
#
# Epoch 232 Train - Loss : 0.077171, PSNR : 18.01 dB
# Epoch 232 Valid - Loss : 0.278092, PSNR : 3.447323 dB
# Current Learning Rate : 0.001
#
# Epoch 233 Train - Loss : 0.077631, PSNR : 17.64 dB
# Epoch 233 Valid - Loss : 0.084303, PSNR : 18.034329 dB
# Current Learning Rate : 0.001
#
# Epoch 234 Train - Loss : 0.079766, PSNR : 17.69 dB
# Epoch 234 Valid - Loss : 0.095147, PSNR : 16.818052 dB
# Current Learning Rate : 0.001
#
# Epoch 235 Train - Loss : 0.080615, PSNR : 17.61 dB
# Epoch 235 Valid - Loss : 0.105868, PSNR : 15.476559 dB
# Current Learning Rate : 0.001
#
# Epoch 236 Train - Loss : 0.075141, PSNR : 18.28 dB
# Epoch 236 Valid - Loss : 0.125966, PSNR : 13.246248 dB
# Current Learning Rate : 0.001
#
# Epoch 237 Train - Loss : 0.070189, PSNR : 18.80 dB
# Epoch 237 Valid - Loss : 1.134985, PSNR : -7.284214 dB
# Current Learning Rate : 0.001
#
# Epoch 238 Train - Loss : 0.077375, PSNR : 18.18 dB
# Epoch 238 Valid - Loss : 1.928920, PSNR : -11.293084 dB
# Current Learning Rate : 0.001
#
# Epoch 239 Train - Loss : 0.074595, PSNR : 18.42 dB
# Epoch 239 Valid - Loss : 0.641482, PSNR : -2.868188 dB
# Current Learning Rate : 0.001
#
# Epoch 240 Train - Loss : 0.077805, PSNR : 18.21 dB
# Epoch 240 Valid - Loss : 0.133973, PSNR : 12.716163 dB
# Current Learning Rate : 0.001
#
# Epoch 241 Train - Loss : 0.074449, PSNR : 18.56 dB
# Epoch 241 Valid - Loss : 0.091402, PSNR : 17.052237 dB
# Current Learning Rate : 0.001
#
# Epoch 242 Train - Loss : 0.075366, PSNR : 18.47 dB
# Epoch 242 Valid - Loss : 0.087793, PSNR : 17.507909 dB
# Current Learning Rate : 0.001
#
# Epoch 243 Train - Loss : 0.073739, PSNR : 18.65 dB
# Epoch 243 Valid - Loss : 0.087797, PSNR : 17.821829 dB
# Current Learning Rate : 0.001
#
# Epoch 244 Train - Loss : 0.083791, PSNR : 17.69 dB
# Epoch 244 Valid - Loss : 0.241732, PSNR : 5.404488 dB
# Current Learning Rate : 0.001
#
# Epoch 245 Train - Loss : 0.077902, PSNR : 18.14 dB
# Epoch 245 Valid - Loss : 0.103712, PSNR : 15.902186 dB
# Current Learning Rate : 0.001
#
# Epoch 246 Train - Loss : 0.071347, PSNR : 18.71 dB
# Epoch 246 Valid - Loss : 0.082932, PSNR : 17.195427 dB
# Current Learning Rate : 0.001
#
# Epoch 247 Train - Loss : 0.073255, PSNR : 18.12 dB
# Epoch 247 Valid - Loss : 0.097864, PSNR : 16.943212 dB
# Current Learning Rate : 0.001
#
# Epoch 248 Train - Loss : 0.079303, PSNR : 17.86 dB
# Epoch 248 Valid - Loss : 0.071175, PSNR : 19.874546 dB
# Current Learning Rate : 0.001
#
# Epoch 249 Train - Loss : 0.071746, PSNR : 18.74 dB
# Epoch 249 Valid - Loss : 0.107532, PSNR : 12.972817 dB
# Current Learning Rate : 0.001
#
# Epoch 250 Train - Loss : 0.072791, PSNR : 17.65 dB
# Epoch 250 Valid - Loss : 0.182112, PSNR : 6.927721 dB
# Current Learning Rate : 0.001
#
# Epoch 251 Train - Loss : 0.066989, PSNR : 18.77 dB
# Epoch 251 Valid - Loss : 0.072660, PSNR : 19.407251 dB
# Current Learning Rate : 0.001
#
# Epoch 252 Train - Loss : 0.070708, PSNR : 18.59 dB
# Epoch 252 Valid - Loss : 0.069032, PSNR : 19.789587 dB
# Current Learning Rate : 0.001
#
# Epoch 253 Train - Loss : 0.068710, PSNR : 19.03 dB
# Epoch 253 Valid - Loss : 0.080547, PSNR : 18.515769 dB
# Current Learning Rate : 0.001
#
# Epoch 254 Train - Loss : 0.076285, PSNR : 18.17 dB
# Epoch 254 Valid - Loss : 0.081859, PSNR : 16.971211 dB
# Current Learning Rate : 0.001
#
# Epoch 255 Train - Loss : 0.068433, PSNR : 19.08 dB
# Epoch 255 Valid - Loss : 0.075433, PSNR : 18.809696 dB
# Current Learning Rate : 0.001
#
# Epoch 256 Train - Loss : 0.059879, PSNR : 19.62 dB
# Epoch 256 Valid - Loss : 0.081695, PSNR : 16.739596 dB
# Current Learning Rate : 0.001
#
# Epoch 257 Train - Loss : 0.069310, PSNR : 18.54 dB
# Epoch 257 Valid - Loss : 0.073150, PSNR : 19.060542 dB
# Current Learning Rate : 0.001
#
# Epoch 258 Train - Loss : 0.075057, PSNR : 18.09 dB
# Epoch 258 Valid - Loss : 0.073766, PSNR : 19.345966 dB
# Current Learning Rate : 0.001
#
# Epoch 259 Train - Loss : 0.073594, PSNR : 18.37 dB
# Epoch 259 Valid - Loss : 0.832139, PSNR : -7.672861 dB
# Current Learning Rate : 0.001
#
# Epoch 260 Train - Loss : 0.076577, PSNR : 18.09 dB
# Epoch 260 Valid - Loss : 0.126328, PSNR : 12.642678 dB
# Current Learning Rate : 0.001
#
# Epoch 261 Train - Loss : 0.070623, PSNR : 18.90 dB
# Epoch 261 Valid - Loss : 0.093782, PSNR : 17.245006 dB
# Current Learning Rate : 0.001
#
# Epoch 262 Train - Loss : 0.072074, PSNR : 18.87 dB
# Epoch 262 Valid - Loss : 0.077179, PSNR : 18.607337 dB
# Current Learning Rate : 0.001
#
# Epoch 263 Train - Loss : 0.072468, PSNR : 18.61 dB
# Epoch 263 Valid - Loss : 0.079370, PSNR : 18.665225 dB
# Current Learning Rate : 0.001
#
# Epoch 264 Train - Loss : 0.065208, PSNR : 19.23 dB
# Epoch 264 Valid - Loss : 0.076730, PSNR : 18.740840 dB
# Current Learning Rate : 0.001
#
# Epoch 265 Train - Loss : 0.074682, PSNR : 18.64 dB
# Epoch 265 Valid - Loss : 0.081625, PSNR : 18.130951 dB
# Current Learning Rate : 0.001
#
# Epoch 266 Train - Loss : 0.069729, PSNR : 18.94 dB
# Epoch 266 Valid - Loss : 0.072214, PSNR : 19.346931 dB
# Current Learning Rate : 0.001
#
# Epoch 267 Train - Loss : 0.062810, PSNR : 19.55 dB
# Epoch 267 Valid - Loss : 0.079561, PSNR : 18.239792 dB
# Current Learning Rate : 0.001
#
# Epoch 268 Train - Loss : 0.066956, PSNR : 19.26 dB
# Epoch 268 Valid - Loss : 0.092860, PSNR : 16.356746 dB
# Current Learning Rate : 0.001
#
# Epoch 269 Train - Loss : 0.062692, PSNR : 19.62 dB
# Epoch 269 Valid - Loss : 0.099168, PSNR : 14.102614 dB
# Current Learning Rate : 0.001
#
# Epoch 270 Train - Loss : 0.069949, PSNR : 19.05 dB
# Epoch 270 Valid - Loss : 0.082184, PSNR : 18.092230 dB
# Current Learning Rate : 0.001
#
# Epoch 271 Train - Loss : 0.077734, PSNR : 17.65 dB
# Epoch 271 Valid - Loss : 0.132622, PSNR : 10.774552 dB
# Current Learning Rate : 0.001
#
# Epoch 272 Train - Loss : 0.082364, PSNR : 16.52 dB
# Epoch 272 Valid - Loss : 28.058317, PSNR : -30.431465 dB
# Current Learning Rate : 0.001
#
# Epoch 273 Train - Loss : 0.092802, PSNR : 16.10 dB
# Epoch 273 Valid - Loss : 13.215195, PSNR : -24.635559 dB
# Current Learning Rate : 0.001
#
# Epoch 274 Train - Loss : 0.092493, PSNR : 16.27 dB
# Epoch 274 Valid - Loss : 0.389390, PSNR : -0.073191 dB
# Current Learning Rate : 0.001
#
# Epoch 275 Train - Loss : 0.094557, PSNR : 15.81 dB
# Epoch 275 Valid - Loss : 0.089299, PSNR : 18.129067 dB
# Current Learning Rate : 0.001
#
# Epoch 276 Train - Loss : 0.083791, PSNR : 17.01 dB
# Epoch 276 Valid - Loss : 0.082557, PSNR : 18.322501 dB
# Current Learning Rate : 0.001
#
# Epoch 277 Train - Loss : 0.083059, PSNR : 16.93 dB
# Epoch 277 Valid - Loss : 0.136976, PSNR : 11.501360 dB
# Current Learning Rate : 0.001
#
# Epoch 278 Train - Loss : 0.092733, PSNR : 16.44 dB
# Epoch 278 Valid - Loss : 0.079088, PSNR : 18.512624 dB
# Current Learning Rate : 0.001
#
# Epoch 279 Train - Loss : 0.083568, PSNR : 17.33 dB
# Epoch 279 Valid - Loss : 0.095341, PSNR : 17.682520 dB
# Current Learning Rate : 0.001
#
# Epoch 280 Train - Loss : 0.078445, PSNR : 17.24 dB
# Epoch 280 Valid - Loss : 0.082125, PSNR : 18.322961 dB
# Current Learning Rate : 0.001
#
# Epoch 281 Train - Loss : 0.076195, PSNR : 17.73 dB
# Epoch 281 Valid - Loss : 0.080165, PSNR : 18.515449 dB
# Current Learning Rate : 0.001
#
# Epoch 282 Train - Loss : 0.077666, PSNR : 17.54 dB
# Epoch 282 Valid - Loss : 0.091830, PSNR : 17.817220 dB
# Current Learning Rate : 0.001
#
# Epoch 283 Train - Loss : 0.079752, PSNR : 17.22 dB
# Epoch 283 Valid - Loss : 0.067113, PSNR : 19.827472 dB
# Current Learning Rate : 0.001
#
# Epoch 284 Train - Loss : 0.088016, PSNR : 17.37 dB
# Epoch 284 Valid - Loss : 0.087668, PSNR : 17.923865 dB
# Current Learning Rate : 0.001
#
# Epoch 285 Train - Loss : 0.075032, PSNR : 18.89 dB
# Epoch 285 Valid - Loss : 0.085213, PSNR : 17.846835 dB
# Current Learning Rate : 0.001
#
# Epoch 286 Train - Loss : 0.070069, PSNR : 18.75 dB
# Epoch 286 Valid - Loss : 0.075898, PSNR : 18.962347 dB
# Current Learning Rate : 0.001
#
# Epoch 287 Train - Loss : 0.067790, PSNR : 18.89 dB
# Epoch 287 Valid - Loss : 0.068628, PSNR : 20.003939 dB
# Current Learning Rate : 0.001
#
# Epoch 288 Train - Loss : 0.076135, PSNR : 18.62 dB
# Epoch 288 Valid - Loss : 0.081285, PSNR : 18.244370 dB
# Current Learning Rate : 0.001
#
# Epoch 289 Train - Loss : 0.064662, PSNR : 19.46 dB
# Epoch 289 Valid - Loss : 0.088647, PSNR : 18.018898 dB
# Current Learning Rate : 0.001
#
# Epoch 290 Train - Loss : 0.077110, PSNR : 17.70 dB
# Epoch 290 Valid - Loss : 0.069923, PSNR : 19.580771 dB
# Current Learning Rate : 0.001
#
# Epoch 291 Train - Loss : 0.076427, PSNR : 17.76 dB
# Epoch 291 Valid - Loss : 0.074156, PSNR : 18.775725 dB
# Current Learning Rate : 0.001
#
# Epoch 292 Train - Loss : 0.079637, PSNR : 17.30 dB
# Epoch 292 Valid - Loss : 0.067445, PSNR : 19.541137 dB
# Current Learning Rate : 0.001
#
# Epoch 293 Train - Loss : 0.071280, PSNR : 18.30 dB
# Epoch 293 Valid - Loss : 0.077049, PSNR : 18.419446 dB
# Current Learning Rate : 0.001
#
# Epoch 294 Train - Loss : 0.076906, PSNR : 17.80 dB
# Epoch 294 Valid - Loss : 0.075838, PSNR : 18.659832 dB
# Current Learning Rate : 0.001
#
# Epoch 295 Train - Loss : 0.070939, PSNR : 18.42 dB
# Epoch 295 Valid - Loss : 0.081724, PSNR : 18.104605 dB
# Current Learning Rate : 0.001
#
# Epoch 296 Train - Loss : 0.073512, PSNR : 18.43 dB
# Epoch 296 Valid - Loss : 0.084428, PSNR : 18.166321 dB
# Current Learning Rate : 0.001
#
# Epoch 297 Train - Loss : 0.069371, PSNR : 18.95 dB
# Epoch 297 Valid - Loss : 0.081377, PSNR : 18.263355 dB
# Current Learning Rate : 0.001
#
# Epoch 298 Train - Loss : 0.070228, PSNR : 18.82 dB
# Epoch 298 Valid - Loss : 0.076133, PSNR : 19.032583 dB
# Current Learning Rate : 0.001
#
# Epoch 299 Train - Loss : 0.066790, PSNR : 19.14 dB
# Epoch 299 Valid - Loss : 0.068938, PSNR : 20.189959 dB
# Current Learning Rate : 0.001
#
# Epoch 300 Train - Loss : 0.070044, PSNR : 19.02 dB
# Epoch 300 Valid - Loss : 0.081072, PSNR : 18.395222 dB
# Current Learning Rate : 0.001
#
# Epoch 301 Train - Loss : 0.076606, PSNR : 18.26 dB
# Epoch 301 Valid - Loss : 0.068642, PSNR : 20.763903 dB
# Current Learning Rate : 0.001
#
# Epoch 302 Train - Loss : 0.065872, PSNR : 19.24 dB
# Epoch 302 Valid - Loss : 8.438354, PSNR : -23.136157 dB
# Current Learning Rate : 0.001
#
# Epoch 303 Train - Loss : 0.065178, PSNR : 19.50 dB
# Epoch 303 Valid - Loss : 1.252672, PSNR : -6.929369 dB
# Current Learning Rate : 0.001
#
# Epoch 304 Train - Loss : 0.074719, PSNR : 18.82 dB
# Epoch 304 Valid - Loss : 0.183042, PSNR : 10.079705 dB
# Current Learning Rate : 0.001
#
# Epoch 305 Train - Loss : 0.070280, PSNR : 18.78 dB
# Epoch 305 Valid - Loss : 0.139755, PSNR : 11.401329 dB
# Current Learning Rate : 0.001
#
# Epoch 306 Train - Loss : 0.066489, PSNR : 19.48 dB
# Epoch 306 Valid - Loss : 0.081336, PSNR : 17.190074 dB
# Current Learning Rate : 0.001
#
# Epoch 307 Train - Loss : 0.069937, PSNR : 19.05 dB
# Epoch 307 Valid - Loss : 0.074436, PSNR : 18.480965 dB
# Current Learning Rate : 0.001
#
# Epoch 308 Train - Loss : 0.071990, PSNR : 18.93 dB
# Epoch 308 Valid - Loss : 0.067838, PSNR : 19.755373 dB
# Current Learning Rate : 0.001
#
# Epoch 309 Train - Loss : 0.066067, PSNR : 19.28 dB
# Epoch 309 Valid - Loss : 0.077115, PSNR : 18.628911 dB
# Current Learning Rate : 0.001
#
# Epoch 310 Train - Loss : 0.063167, PSNR : 19.86 dB
# Epoch 310 Valid - Loss : 0.074503, PSNR : 18.887514 dB
# Current Learning Rate : 0.001
#
# Epoch 311 Train - Loss : 0.069963, PSNR : 18.95 dB
# Epoch 311 Valid - Loss : 0.075427, PSNR : 18.447503 dB
# Current Learning Rate : 0.001
#
# Epoch 312 Train - Loss : 0.060175, PSNR : 19.55 dB
# Epoch 312 Valid - Loss : 0.270879, PSNR : 4.607211 dB
# Current Learning Rate : 0.001
#
# Epoch 313 Train - Loss : 0.067155, PSNR : 19.11 dB
# Epoch 313 Valid - Loss : 0.107256, PSNR : 14.706458 dB
# Current Learning Rate : 0.001
#
# Epoch 314 Train - Loss : 0.077873, PSNR : 18.15 dB
# Epoch 314 Valid - Loss : 0.082556, PSNR : 17.555356 dB
# Current Learning Rate : 0.001
#
# Epoch 315 Train - Loss : 0.058551, PSNR : 20.28 dB
# Epoch 315 Valid - Loss : 0.081699, PSNR : 18.142722 dB
# Current Learning Rate : 0.001
#
# Epoch 316 Train - Loss : 0.073082, PSNR : 18.92 dB
# Epoch 316 Valid - Loss : 0.070067, PSNR : 19.257915 dB
# Current Learning Rate : 0.001
#
# Epoch 317 Train - Loss : 0.065333, PSNR : 19.50 dB
# Epoch 317 Valid - Loss : 0.088351, PSNR : 18.148276 dB
# Current Learning Rate : 0.001
#
# Epoch 318 Train - Loss : 0.067853, PSNR : 19.15 dB
# Epoch 318 Valid - Loss : 0.062862, PSNR : 20.200981 dB
# Current Learning Rate : 0.001
#
# Epoch 319 Train - Loss : 0.065637, PSNR : 19.39 dB
# Epoch 319 Valid - Loss : 0.086033, PSNR : 18.135331 dB
# Current Learning Rate : 0.001
#
# Epoch 320 Train - Loss : 0.068177, PSNR : 19.21 dB
# Epoch 320 Valid - Loss : 0.070536, PSNR : 19.534225 dB
# Current Learning Rate : 0.001
#
# Epoch 321 Train - Loss : 0.065605, PSNR : 19.53 dB
# Epoch 321 Valid - Loss : 0.076884, PSNR : 18.782366 dB
# Current Learning Rate : 0.001
#
# Epoch 322 Train - Loss : 0.063889, PSNR : 19.85 dB
# Epoch 322 Valid - Loss : 0.082169, PSNR : 18.540436 dB
# Current Learning Rate : 0.001
#
# Epoch 323 Train - Loss : 0.065049, PSNR : 19.66 dB
# Epoch 323 Valid - Loss : 0.077826, PSNR : 18.448896 dB
# Current Learning Rate : 0.001
#
# Epoch 324 Train - Loss : 0.059434, PSNR : 19.98 dB
# Epoch 324 Valid - Loss : 0.066818, PSNR : 19.590859 dB
# Current Learning Rate : 0.001
#
# Epoch 325 Train - Loss : 0.067262, PSNR : 19.20 dB
# Epoch 325 Valid - Loss : 0.060998, PSNR : 20.653159 dB
# Current Learning Rate : 0.001
#
# Epoch 326 Train - Loss : 0.065293, PSNR : 19.24 dB
# Epoch 326 Valid - Loss : 0.064863, PSNR : 20.042177 dB
# Current Learning Rate : 0.001
#
# Epoch 327 Train - Loss : 0.059078, PSNR : 20.23 dB
# Epoch 327 Valid - Loss : 0.095628, PSNR : 16.516342 dB
# Current Learning Rate : 0.001
#
# Epoch 328 Train - Loss : 0.057961, PSNR : 20.23 dB
# Epoch 328 Valid - Loss : 0.073245, PSNR : 18.702824 dB
# Current Learning Rate : 0.001
#
# Epoch 329 Train - Loss : 0.064213, PSNR : 19.13 dB
# Epoch 329 Valid - Loss : 0.074106, PSNR : 19.134355 dB
# Current Learning Rate : 0.001
#
# Epoch 330 Train - Loss : 0.062770, PSNR : 19.38 dB
# Epoch 330 Valid - Loss : 0.087356, PSNR : 16.641953 dB
# Current Learning Rate : 0.001
#
# Epoch 331 Train - Loss : 0.064309, PSNR : 19.44 dB
# Epoch 331 Valid - Loss : 0.072363, PSNR : 18.742204 dB
# Current Learning Rate : 0.001
#
# Epoch 332 Train - Loss : 0.067014, PSNR : 19.46 dB
# Epoch 332 Valid - Loss : 0.074451, PSNR : 18.929815 dB
# Current Learning Rate : 0.001
#
# Epoch 333 Train - Loss : 0.059167, PSNR : 19.85 dB
# Epoch 333 Valid - Loss : 0.064532, PSNR : 20.063669 dB
# Current Learning Rate : 0.001
#
# Epoch 334 Train - Loss : 0.064757, PSNR : 19.38 dB
# Epoch 334 Valid - Loss : 0.078904, PSNR : 18.541537 dB
# Current Learning Rate : 0.001
#
# Epoch 335 Train - Loss : 0.067435, PSNR : 18.59 dB
# Epoch 335 Valid - Loss : 0.072591, PSNR : 19.434488 dB
# Current Learning Rate : 0.001
#
# Epoch 336 Train - Loss : 0.072888, PSNR : 17.27 dB
# Epoch 336 Valid - Loss : 0.074715, PSNR : 19.040351 dB
# Current Learning Rate : 0.001
#
# Epoch 337 Train - Loss : 0.075984, PSNR : 17.27 dB
# Epoch 337 Valid - Loss : 0.098198, PSNR : 15.222707 dB
# Current Learning Rate : 0.001
#
# Epoch 338 Train - Loss : 0.074071, PSNR : 17.82 dB
# Epoch 338 Valid - Loss : 0.079256, PSNR : 18.415126 dB
# Current Learning Rate : 0.001
#
# Epoch 339 Train - Loss : 0.068012, PSNR : 19.06 dB
# Epoch 339 Valid - Loss : 0.089224, PSNR : 17.496653 dB
# Current Learning Rate : 0.001
#
# Epoch 340 Train - Loss : 0.063972, PSNR : 19.70 dB
# Epoch 340 Valid - Loss : 0.082344, PSNR : 18.225689 dB
# Current Learning Rate : 0.001
#
# Epoch 341 Train - Loss : 0.064013, PSNR : 19.49 dB
# Epoch 341 Valid - Loss : 0.072662, PSNR : 18.984589 dB
# Current Learning Rate : 0.001
#
# Epoch 342 Train - Loss : 0.064120, PSNR : 19.81 dB
# Epoch 342 Valid - Loss : 0.210821, PSNR : 7.552299 dB
# Current Learning Rate : 0.001
#
# Epoch 343 Train - Loss : 0.059778, PSNR : 20.14 dB
# Epoch 343 Valid - Loss : 0.164568, PSNR : 10.144867 dB
# Current Learning Rate : 0.001
#
# Epoch 344 Train - Loss : 0.059848, PSNR : 19.94 dB
# Epoch 344 Valid - Loss : 0.132134, PSNR : 11.995770 dB
# Current Learning Rate : 0.001
#
# Epoch 345 Train - Loss : 0.064402, PSNR : 19.44 dB
# Epoch 345 Valid - Loss : 0.105701, PSNR : 13.714264 dB
# Current Learning Rate : 0.001
#
# Epoch 346 Train - Loss : 0.061394, PSNR : 19.89 dB
# Epoch 346 Valid - Loss : 0.077236, PSNR : 17.707656 dB
# Current Learning Rate : 0.001
#
# Epoch 347 Train - Loss : 0.063757, PSNR : 19.48 dB
# Epoch 347 Valid - Loss : 0.078337, PSNR : 18.709143 dB
# Current Learning Rate : 0.001
#
# Epoch 348 Train - Loss : 0.062247, PSNR : 19.84 dB
# Epoch 348 Valid - Loss : 0.072286, PSNR : 19.262085 dB
# Current Learning Rate : 0.001
#
# Epoch 349 Train - Loss : 0.063513, PSNR : 19.77 dB
# Epoch 349 Valid - Loss : 0.081048, PSNR : 18.297105 dB
# Current Learning Rate : 0.001
#
# Epoch 350 Train - Loss : 0.059259, PSNR : 20.24 dB
# Epoch 350 Valid - Loss : 0.087542, PSNR : 17.616431 dB
# Current Learning Rate : 0.001
#
# Epoch 351 Train - Loss : 0.065953, PSNR : 19.32 dB
# Epoch 351 Valid - Loss : 0.121657, PSNR : 13.795992 dB
# Current Learning Rate : 0.001
#
# Epoch 352 Train - Loss : 0.062144, PSNR : 19.91 dB
# Epoch 352 Valid - Loss : 0.071272, PSNR : 19.059148 dB
# Current Learning Rate : 0.001
#
# ...
# Current Learning Rate : 0.001
#
# Epoch 385 Train - Loss : 0.063214, PSNR : 19.75 dB
# Epoch 385 Valid - Loss : 0.079531, PSNR : 18.351747 dB
# Current Learning Rate : 0.001
#
# Epoch 386 Train - Loss : 0.067248, PSNR : 19.13 dB
# Epoch 386 Valid - Loss : 0.073209, PSNR : 19.073508 dB
# Current Learning Rate : 0.001
#
# Epoch 387 Train - Loss : 0.062544, PSNR : 19.75 dB
# Epoch 387 Valid - Loss : 0.069783, PSNR : 19.229222 dB
# Current Learning Rate : 0.001
#
# Epoch 388 Train - Loss : 0.063345, PSNR : 19.58 dB
# Epoch 388 Valid - Loss : 0.071460, PSNR : 19.000117 dB
# Current Learning Rate : 0.001
#
# Epoch 389 Train - Loss : 0.065817, PSNR : 19.31 dB
# Epoch 389 Valid - Loss : 0.433887, PSNR : 1.342094 dB
# Current Learning Rate : 0.001
#
# Epoch 390 Train - Loss : 0.071415, PSNR : 18.76 dB
# Epoch 390 Valid - Loss : 0.137543, PSNR : 12.105316 dB
# Current Learning Rate : 0.001
#
# Epoch 391 Train - Loss : 0.066853, PSNR : 19.36 dB
# Epoch 391 Valid - Loss : 0.082347, PSNR : 17.793625 dB
# Current Learning Rate : 0.001
#
# Epoch 392 Train - Loss : 0.061444, PSNR : 20.05 dB
# Epoch 392 Valid - Loss : 0.068730, PSNR : 19.611240 dB
# Current Learning Rate : 0.001
#
# Epoch 393 Train - Loss : 0.062942, PSNR : 19.73 dB
# Epoch 393 Valid - Loss : 0.072590, PSNR : 19.278310 dB
# Current Learning Rate : 0.001
#
# Epoch 394 Train - Loss : 0.066633, PSNR : 19.09 dB
# Epoch 394 Valid - Loss : 0.077519, PSNR : 18.655810 dB
# Current Learning Rate : 0.001
#
# Epoch 395 Train - Loss : 0.068784, PSNR : 18.88 dB
# Epoch 395 Valid - Loss : 0.072013, PSNR : 19.338853 dB
# Current Learning Rate : 0.001
#
# Epoch 396 Train - Loss : 0.060953, PSNR : 19.89 dB
# Epoch 396 Valid - Loss : 0.070696, PSNR : 18.978526 dB
# Current Learning Rate : 0.001
#
# Epoch 397 Train - Loss : 0.071113, PSNR : 18.98 dB
# Epoch 397 Valid - Loss : 0.065629, PSNR : 19.796977 dB
# Current Learning Rate : 0.001
#
# Epoch 398 Train - Loss : 0.059836, PSNR : 20.27 dB
# Epoch 398 Valid - Loss : 0.076405, PSNR : 18.627216 dB
# Current Learning Rate : 0.001
#
# Epoch 399 Train - Loss : 0.067824, PSNR : 19.25 dB
# Epoch 399 Valid - Loss : 0.071781, PSNR : 17.056314 dB
# Current Learning Rate : 0.001
#
# Epoch 400 Train - Loss : 0.065798, PSNR : 19.26 dB
# Epoch 400 Valid - Loss : 0.079467, PSNR : 17.911620 dB
# Current Learning Rate : 0.001
#
# Epoch 401 Train - Loss : 0.067325, PSNR : 19.05 dB
# Epoch 401 Valid - Loss : 0.079911, PSNR : 18.708417 dB
# Current Learning Rate : 0.001
#
# Epoch 402 Train - Loss : 0.069140, PSNR : 19.17 dB
# Epoch 402 Valid - Loss : 0.076718, PSNR : 18.539398 dB
# Current Learning Rate : 0.001
#
# Epoch 403 Train - Loss : 0.064999, PSNR : 19.34 dB
# Epoch 403 Valid - Loss : 0.065418, PSNR : 19.242753 dB
# Current Learning Rate : 0.001
#
# Epoch 404 Train - Loss : 0.069945, PSNR : 19.03 dB
# Epoch 404 Valid - Loss : 0.079675, PSNR : 18.598522 dB
# Current Learning Rate : 0.001
#
# Epoch 405 Train - Loss : 0.053673, PSNR : 20.98 dB
# Epoch 405 Valid - Loss : 0.065580, PSNR : 19.939350 dB
# Current Learning Rate : 0.001
#
# Epoch 406 Train - Loss : 0.069058, PSNR : 19.16 dB
# Epoch 406 Valid - Loss : 0.073433, PSNR : 18.900089 dB
# Current Learning Rate : 0.001
#
# Epoch 407 Train - Loss : 0.065988, PSNR : 19.40 dB
# Epoch 407 Valid - Loss : 0.080408, PSNR : 18.404345 dB
# Current Learning Rate : 0.001
#
# Epoch 408 Train - Loss : 0.066374, PSNR : 19.39 dB
# Epoch 408 Valid - Loss : 0.062728, PSNR : 20.218529 dB
# Current Learning Rate : 0.001
#
# Epoch 409 Train - Loss : 0.064680, PSNR : 19.62 dB
# Epoch 409 Valid - Loss : 0.074608, PSNR : 18.782328 dB
# Current Learning Rate : 0.001
#
# Epoch 410 Train - Loss : 0.064361, PSNR : 19.57 dB
# Epoch 410 Valid - Loss : 0.079928, PSNR : 18.311990 dB
# Current Learning Rate : 0.001
#
# Epoch 411 Train - Loss : 0.061017, PSNR : 20.18 dB
# Epoch 411 Valid - Loss : 0.082194, PSNR : 18.149226 dB
# Current Learning Rate : 0.001
#
# Epoch 412 Train - Loss : 0.058761, PSNR : 20.16 dB
# Epoch 412 Valid - Loss : 0.076215, PSNR : 18.659964 dB
# Current Learning Rate : 0.001
#
# Epoch 413 Train - Loss : 0.062653, PSNR : 19.74 dB
# Epoch 413 Valid - Loss : 0.077958, PSNR : 18.537436 dB
# Current Learning Rate : 0.001
#
# Epoch 414 Train - Loss : 0.062920, PSNR : 19.68 dB
# Epoch 414 Valid - Loss : 0.077623, PSNR : 18.574728 dB
# Current Learning Rate : 0.001
#
# Epoch 415 Train - Loss : 0.063827, PSNR : 19.59 dB
# Epoch 415 Valid - Loss : 0.078683, PSNR : 18.461523 dB
# Current Learning Rate : 0.001
#
# Epoch 416 Train - Loss : 0.058774, PSNR : 19.96 dB
# Epoch 416 Valid - Loss : 0.089635, PSNR : 17.734164 dB
# Current Learning Rate : 0.001
#
# Epoch 417 Train - Loss : 0.063364, PSNR : 19.78 dB
# Epoch 417 Valid - Loss : 0.080665, PSNR : 18.142536 dB
# Current Learning Rate : 0.001
#
# Epoch 418 Train - Loss : 0.064233, PSNR : 19.46 dB
# Epoch 418 Valid - Loss : 0.064879, PSNR : 20.440474 dB
# Current Learning Rate : 0.001
#
# Epoch 419 Train - Loss : 0.066644, PSNR : 19.30 dB
# Epoch 419 Valid - Loss : 0.071214, PSNR : 19.242189 dB
# Current Learning Rate : 0.001
#
# Epoch 420 Train - Loss : 0.059345, PSNR : 20.28 dB
# Epoch 420 Valid - Loss : 0.073657, PSNR : 19.088380 dB
# Current Learning Rate : 0.001
#
# Epoch 421 Train - Loss : 0.062337, PSNR : 19.71 dB
# Epoch 421 Valid - Loss : 0.076202, PSNR : 18.409535 dB
# Current Learning Rate : 0.001
#
# Epoch 422 Train - Loss : 0.069541, PSNR : 19.38 dB
# Epoch 422 Valid - Loss : 0.085892, PSNR : 17.228455 dB
# Current Learning Rate : 0.001
#
# Epoch 423 Train - Loss : 0.062909, PSNR : 19.64 dB
# Epoch 423 Valid - Loss : 0.076464, PSNR : 18.314117 dB
# Current Learning Rate : 0.001
#
# Epoch 424 Train - Loss : 0.054709, PSNR : 20.37 dB
# Epoch 424 Valid - Loss : 0.072146, PSNR : 18.661356 dB
# Current Learning Rate : 0.001
#
# Epoch 425 Train - Loss : 0.059801, PSNR : 19.96 dB
# Epoch 425 Valid - Loss : 0.059792, PSNR : 20.545373 dB
# Current Learning Rate : 0.001
#
# Epoch 426 Train - Loss : 0.064977, PSNR : 19.47 dB
# Epoch 426 Valid - Loss : 0.070719, PSNR : 19.183879 dB
# Current Learning Rate : 0.001
#
# Epoch 427 Train - Loss : 0.062679, PSNR : 19.80 dB
# Epoch 427 Valid - Loss : 0.072034, PSNR : 18.844008 dB
# Current Learning Rate : 0.001
#
# Epoch 428 Train - Loss : 0.062192, PSNR : 19.74 dB
# Epoch 428 Valid - Loss : 0.079730, PSNR : 17.777788 dB
# Current Learning Rate : 0.001
#
# Epoch 429 Train - Loss : 0.064654, PSNR : 19.83 dB
# Epoch 429 Valid - Loss : 0.074141, PSNR : 18.255959 dB
# Current Learning Rate : 0.001
#
# Epoch 430 Train - Loss : 0.063689, PSNR : 19.86 dB
# Epoch 430 Valid - Loss : 0.077488, PSNR : 18.554798 dB
# Current Learning Rate : 0.001
#
# Epoch 431 Train - Loss : 0.060325, PSNR : 19.89 dB
# Epoch 431 Valid - Loss : 0.082706, PSNR : 17.993921 dB
# Current Learning Rate : 0.001
#
# Epoch 432 Train - Loss : 0.066002, PSNR : 19.35 dB
# Epoch 432 Valid - Loss : 0.076629, PSNR : 18.343588 dB
# Current Learning Rate : 0.001
#
# Epoch 433 Train - Loss : 0.061970, PSNR : 19.74 dB
# Epoch 433 Valid - Loss : 0.074911, PSNR : 18.686983 dB
# Current Learning Rate : 0.001
#
# Epoch 434 Train - Loss : 0.069337, PSNR : 19.17 dB
# Epoch 434 Valid - Loss : 0.075357, PSNR : 18.333528 dB
# Current Learning Rate : 0.001
#
# Epoch 435 Train - Loss : 0.066808, PSNR : 18.55 dB
# Epoch 435 Valid - Loss : 0.089060, PSNR : 17.466990 dB
# Current Learning Rate : 0.001
#
# Epoch 436 Train - Loss : 0.072376, PSNR : 17.74 dB
# Epoch 436 Valid - Loss : 0.077699, PSNR : 18.549954 dB
# Current Learning Rate : 0.001
#
# Epoch 437 Train - Loss : 0.074964, PSNR : 17.46 dB
# Epoch 437 Valid - Loss : 0.066642, PSNR : 19.949325 dB
# Current Learning Rate : 0.001
#
# Epoch 438 Train - Loss : 0.072179, PSNR : 17.74 dB
# Epoch 438 Valid - Loss : 0.076422, PSNR : 18.560607 dB
# Current Learning Rate : 0.001
#
# Epoch 439 Train - Loss : 0.070471, PSNR : 18.76 dB
# Epoch 439 Valid - Loss : 0.076413, PSNR : 18.879230 dB
# Current Learning Rate : 0.001
#
# Epoch 440 Train - Loss : 0.068367, PSNR : 18.67 dB
# Epoch 440 Valid - Loss : 0.073852, PSNR : 19.079996 dB
# Current Learning Rate : 0.001
#
# Epoch 441 Train - Loss : 0.063764, PSNR : 19.16 dB
# Epoch 441 Valid - Loss : 0.077945, PSNR : 18.880650 dB
# Current Learning Rate : 0.001
#
# Epoch 442 Train - Loss : 0.071876, PSNR : 18.50 dB
# Epoch 442 Valid - Loss : 0.071931, PSNR : 18.710849 dB
# Current Learning Rate : 0.001
#
# Epoch 443 Train - Loss : 0.068050, PSNR : 19.00 dB
# Epoch 443 Valid - Loss : 0.077029, PSNR : 18.530070 dB
# Current Learning Rate : 0.001
#
# Epoch 444 Train - Loss : 0.066595, PSNR : 19.19 dB
# Epoch 444 Valid - Loss : 0.115037, PSNR : 13.713042 dB
# Current Learning Rate : 0.001
#
# Epoch 445 Train - Loss : 0.066278, PSNR : 19.24 dB
# Epoch 445 Valid - Loss : 0.101801, PSNR : 15.097698 dB
# Current Learning Rate : 0.001
#
# Epoch 446 Train - Loss : 0.063862, PSNR : 19.59 dB
# Epoch 446 Valid - Loss : 0.090143, PSNR : 16.625618 dB
# Current Learning Rate : 0.001
#
# Epoch 447 Train - Loss : 0.062726, PSNR : 19.77 dB
# Epoch 447 Valid - Loss : 0.063620, PSNR : 20.185130 dB
# Current Learning Rate : 0.001
#
# Epoch 448 Train - Loss : 0.065071, PSNR : 19.40 dB
# Epoch 448 Valid - Loss : 0.072794, PSNR : 18.943175 dB
# Current Learning Rate : 0.001
#
# Epoch 449 Train - Loss : 0.065886, PSNR : 19.45 dB
# Epoch 449 Valid - Loss : 0.064169, PSNR : 19.962044 dB
# Current Learning Rate : 0.001
#
# Epoch 450 Train - Loss : 0.060355, PSNR : 19.88 dB
# Epoch 450 Valid - Loss : 0.068264, PSNR : 19.011821 dB
# Current Learning Rate : 0.001
#
# Epoch 451 Train - Loss : 0.070270, PSNR : 19.05 dB
# Epoch 451 Valid - Loss : 0.074961, PSNR : 18.731260 dB
# Current Learning Rate : 0.001
#
# Epoch 452 Train - Loss : 0.058315, PSNR : 20.17 dB
# Epoch 452 Valid - Loss : 0.071724, PSNR : 19.306584 dB
# Current Learning Rate : 0.001
#
# Epoch 453 Train - Loss : 0.060368, PSNR : 19.93 dB
# Epoch 453 Valid - Loss : 0.064809, PSNR : 19.872084 dB
# Current Learning Rate : 0.001
#
# Epoch 454 Train - Loss : 0.062600, PSNR : 19.75 dB
# Epoch 454 Valid - Loss : 0.080854, PSNR : 18.226497 dB
# Current Learning Rate : 0.001
#
# Epoch 455 Train - Loss : 0.058325, PSNR : 20.14 dB
# Epoch 455 Valid - Loss : 0.069093, PSNR : 19.573999 dB
# Current Learning Rate : 0.001
#
# Epoch 456 Train - Loss : 0.060454, PSNR : 20.06 dB
# Epoch 456 Valid - Loss : 0.066994, PSNR : 19.645963 dB
# Current Learning Rate : 0.001
#
# Epoch 457 Train - Loss : 0.067619, PSNR : 19.17 dB
# Epoch 457 Valid - Loss : 0.066229, PSNR : 19.787914 dB
# Current Learning Rate : 0.001
#
# Epoch 458 Train - Loss : 0.061758, PSNR : 19.99 dB
# Epoch 458 Valid - Loss : 0.060360, PSNR : 20.701690 dB
# Current Learning Rate : 0.001
#
# Epoch 459 Train - Loss : 0.059296, PSNR : 20.06 dB
# Epoch 459 Valid - Loss : 0.066031, PSNR : 19.348576 dB
# Current Learning Rate : 0.001
#
# Epoch 460 Train - Loss : 0.058600, PSNR : 20.34 dB
# Epoch 460 Valid - Loss : 0.070826, PSNR : 19.339339 dB
# Current Learning Rate : 0.001
#
# Epoch 461 Train - Loss : 0.059527, PSNR : 20.16 dB
# Epoch 461 Valid - Loss : 0.069634, PSNR : 19.520566 dB
# Current Learning Rate : 0.001
#
# Epoch 462 Train - Loss : 0.064815, PSNR : 19.42 dB
# Epoch 462 Valid - Loss : 0.073474, PSNR : 18.592439 dB
# Current Learning Rate : 0.001
#
# Epoch 463 Train - Loss : 0.065218, PSNR : 19.51 dB
# Epoch 463 Valid - Loss : 0.075808, PSNR : 18.604599 dB
# Current Learning Rate : 0.001
#
# Epoch 464 Train - Loss : 0.059838, PSNR : 20.03 dB
# Epoch 464 Valid - Loss : 0.077207, PSNR : 18.378007 dB
# Current Learning Rate : 0.001
#
# Epoch 465 Train - Loss : 0.058660, PSNR : 19.88 dB
# Epoch 465 Valid - Loss : 0.068682, PSNR : 19.235743 dB
# Current Learning Rate : 0.001
#
# Epoch 466 Train - Loss : 0.058313, PSNR : 20.38 dB
# Epoch 466 Valid - Loss : 0.072156, PSNR : 18.852058 dB
# Current Learning Rate : 0.001
#
# Epoch 467 Train - Loss : 0.062996, PSNR : 19.79 dB
# Epoch 467 Valid - Loss : 0.086592, PSNR : 17.840371 dB
# Current Learning Rate : 0.001
#
# Epoch 468 Train - Loss : 0.057525, PSNR : 20.11 dB
# Epoch 468 Valid - Loss : 0.067300, PSNR : 19.730966 dB
# Current Learning Rate : 0.001
#
# Epoch 469 Train - Loss : 0.061517, PSNR : 19.68 dB
# Epoch 469 Valid - Loss : 0.063876, PSNR : 20.279894 dB
# Current Learning Rate : 0.001
#
# Epoch 470 Train - Loss : 0.056395, PSNR : 20.52 dB
# Epoch 470 Valid - Loss : 0.063553, PSNR : 20.088208 dB
# Current Learning Rate : 0.001
#
# Epoch 471 Train - Loss : 0.060478, PSNR : 19.90 dB
# Epoch 471 Valid - Loss : 0.072182, PSNR : 19.165517 dB
# Current Learning Rate : 0.001
#
# Epoch 472 Train - Loss : 0.059754, PSNR : 19.89 dB
# Epoch 472 Valid - Loss : 0.074559, PSNR : 19.256290 dB
# Current Learning Rate : 0.001
#
# Epoch 473 Train - Loss : 0.053639, PSNR : 20.59 dB
# Epoch 473 Valid - Loss : 0.068099, PSNR : 19.394101 dB
# Current Learning Rate : 0.001
#
# Epoch 474 Train - Loss : 0.059433, PSNR : 19.95 dB
# Epoch 474 Valid - Loss : 0.062103, PSNR : 20.250191 dB
# Current Learning Rate : 0.001
#
# Epoch 475 Train - Loss : 0.061099, PSNR : 19.86 dB
# Epoch 475 Valid - Loss : 0.076898, PSNR : 18.393600 dB
# Current Learning Rate : 0.001
#
# Epoch 476 Train - Loss : 0.066078, PSNR : 19.38 dB
# Epoch 476 Valid - Loss : 0.071550, PSNR : 19.205465 dB
# Current Learning Rate : 0.001
#
# Epoch 477 Train - Loss : 0.061493, PSNR : 19.93 dB
# Epoch 477 Valid - Loss : 0.072614, PSNR : 18.973879 dB
# Current Learning Rate : 0.001
#
# Epoch 478 Train - Loss : 0.062531, PSNR : 19.71 dB
# Epoch 478 Valid - Loss : 0.070141, PSNR : 19.259630 dB
# Current Learning Rate : 0.001
#
# Epoch 479 Train - Loss : 0.053668, PSNR : 20.71 dB
# Epoch 479 Valid - Loss : 0.067700, PSNR : 20.007048 dB
# Current Learning Rate : 0.001
#
# Epoch 480 Train - Loss : 0.064964, PSNR : 19.55 dB
# Epoch 480 Valid - Loss : 0.063753, PSNR : 19.500797 dB
# Current Learning Rate : 0.001
#
# Epoch 481 Train - Loss : 0.058779, PSNR : 20.13 dB
# Epoch 481 Valid - Loss : 0.071507, PSNR : 18.977111 dB
# Current Learning Rate : 0.001
#
# Epoch 482 Train - Loss : 0.059547, PSNR : 20.24 dB
# Epoch 482 Valid - Loss : 0.064549, PSNR : 20.032421 dB
# Current Learning Rate : 0.001
#
# Epoch 483 Train - Loss : 0.059127, PSNR : 20.15 dB
# Epoch 483 Valid - Loss : 0.061440, PSNR : 20.355901 dB
# Current Learning Rate : 0.001
#
# Epoch 484 Train - Loss : 0.059170, PSNR : 19.89 dB
# Epoch 484 Valid - Loss : 0.066663, PSNR : 19.721975 dB
# Current Learning Rate : 0.001
#
# Epoch 485 Train - Loss : 0.061954, PSNR : 19.60 dB
# Epoch 485 Valid - Loss : 0.074615, PSNR : 18.412803 dB
# Current Learning Rate : 0.001
#
# Epoch 486 Train - Loss : 0.055622, PSNR : 20.34 dB
# Epoch 486 Valid - Loss : 0.071106, PSNR : 19.335180 dB
# Current Learning Rate : 0.001
#
# Epoch 487 Train - Loss : 0.061376, PSNR : 19.76 dB
# Epoch 487 Valid - Loss : 0.083901, PSNR : 18.271891 dB
# Current Learning Rate : 0.001
#
# Epoch 488 Train - Loss : 0.059541, PSNR : 19.84 dB
# Epoch 488 Valid - Loss : 0.060831, PSNR : 21.026504 dB
# Current Learning Rate : 0.001
#
# Epoch 489 Train - Loss : 0.057347, PSNR : 20.20 dB
# Epoch 489 Valid - Loss : 0.072182, PSNR : 19.299316 dB
# Current Learning Rate : 0.001
#
# Epoch 490 Train - Loss : 0.060388, PSNR : 20.00 dB
# Epoch 490 Valid - Loss : 0.075514, PSNR : 18.911166 dB
# Current Learning Rate : 0.001
#
# Epoch 491 Train - Loss : 0.060593, PSNR : 19.99 dB
# Epoch 491 Valid - Loss : 0.070950, PSNR : 19.553690 dB
# Current Learning Rate : 0.001
#
# Epoch 492 Train - Loss : 0.064445, PSNR : 19.51 dB
# Epoch 492 Valid - Loss : 0.061252, PSNR : 20.298580 dB
# Current Learning Rate : 0.001
#
# Epoch 493 Train - Loss : 0.067194, PSNR : 19.40 dB
# Epoch 493 Valid - Loss : 0.065804, PSNR : 19.697668 dB
# Current Learning Rate : 0.001
#
# Epoch 494 Train - Loss : 0.059179, PSNR : 19.95 dB
# Epoch 494 Valid - Loss : 0.066550, PSNR : 19.736263 dB
# Current Learning Rate : 0.001
#
# Epoch 495 Train - Loss : 0.059498, PSNR : 19.85 dB
# Epoch 495 Valid - Loss : 0.070042, PSNR : 19.482216 dB
# Current Learning Rate : 0.001
#
# Epoch 496 Train - Loss : 0.061808, PSNR : 19.85 dB
# Epoch 496 Valid - Loss : 0.066398, PSNR : 19.017605 dB
# Current Learning Rate : 0.001
#
# Epoch 497 Train - Loss : 0.058633, PSNR : 20.09 dB
# Epoch 497 Valid - Loss : 0.054495, PSNR : 22.008605 dB
# Current Learning Rate : 0.001
#
# Epoch 498 Train - Loss : 0.060625, PSNR : 19.97 dB
# Epoch 498 Valid - Loss : 0.072623, PSNR : 18.944305 dB
# Current Learning Rate : 0.001
#
# Epoch 499 Train - Loss : 0.059283, PSNR : 19.78 dB
# Epoch 499 Valid - Loss : 0.083410, PSNR : 18.047826 dB
# Current Learning Rate : 0.001
#
# Epoch 500 Train - Loss : 0.059253, PSNR : 20.13 dB
# Epoch 500 Valid - Loss : 0.066625, PSNR : 19.787500 dB
# Current Learning Rate : 0.001
# <All keys matched successfully>

# %%
plt.figure(figsize=(12, 10))
plt.subplot(211)
plt.plot(range(1, n_epochs+1), train_loss, label='Train Loss', color='blue', marker='o')
plt.title("Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True)
plt.legend()

plt.subplot(212)
plt.plot(range(1, n_epochs+1), train_psnr, label='Train PSNR', color='green', marker='*')
plt.plot(range(1, n_epochs+1), val_psnr_hist, label='Val PSNR', color='y', marker='o')
plt.title("Train / Valid PSNR")
plt.xlabel("Epoch")
plt.ylabel("PSNR (dB)")
plt.grid(True)
plt.legend()

# %%
def print_denoised(model, val_loader, num_samples=3):
    model.eval()

    data_iter = iter(val_loader)
    plt.figure(figsize=(15, 5 * num_samples))
    for i in range(num_samples):
        try:
            inputs, targets = next(data_iter)
        except:
            break
        inputs, targets = inputs.to(device), targets.to(device)
        with torch.no_grad():
            outputs = model(inputs)
            denoised_img = inputs - outputs
            denoised_img = torch.clamp(denoised_img, 0.0, 1.0)

        inputs_np = inputs[0].cpu()
        targets_np = targets[0].cpu()
        denoised_np = denoised_img[0].cpu()

        psnr_noisy = calculate_PSNR(inputs_np, targets_np)
        psnr_denoised = calculate_PSNR(denoised_np, targets_np)

        clean_show = targets_np.permute(1, 2, 0).squeeze().numpy()
        noisy_show = inputs_np.permute(1, 2, 0).squeeze().numpy()
        denoised_show = denoised_np.permute(1, 2, 0).squeeze().numpy()

        plt.subplot(num_samples, 3, i*3 +1)
        plt.imshow(clean_show, cmap='gray')
        plt.title(f"Clean (Ground Truth)")
        plt.axis()

        plt.subplot(num_samples, 3, i*3 +2)
        plt.imshow(noisy_show, cmap='gray')
        plt.title(f"Noisy Input\nPSNR : {psnr_noisy:.2f}dB")
        plt.axis()

        plt.subplot(num_samples, 3, i*3 +3)
        plt.imshow(denoised_show, cmap='gray')
        plt.title(f"Denoised Output\nPSNR : {psnr_denoised:.2f}dB")
        plt.axis()

    plt.tight_layout()
    plt.show()

print_denoised(model, val_loader, num_samples=3)

# %%
def worst_case(model, val_loader, num_worst=5):
    model.eval()

    all_results = []

    with torch.no_grad():
        for i, (inputs, targets, _) in enumerate(val_loader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            denoised_img = torch.clamp(inputs - outputs, 0.0, 1.0)

            PSNR = calculate_PSNR(denoised_img, targets).item()

            all_results.append({
                'index' : i,
                'PSNR' : PSNR,
                'inputs' : inputs.cpu(),
                'targets' : targets.cpu(),
                'denoised_img' : denoised_img.cpu()
            })

    # Sort results by PSNR in ascending order (lower PSNR means worse image quality)
    all_results.sort(key=lambda x: x['PSNR'])
    worst_cases = all_results[:num_worst]

    plt.figure(figsize=(20, 4*num_worst)) # Adjust figure width for 5 subplots
    for i, item in enumerate(worst_cases):
        clean = item['targets'][0].permute(1, 2, 0).numpy()
        noisy = item['inputs'][0].permute(1, 2, 0).numpy() # Get the noisy input image
        denoised = item['denoised_img'][0].permute(1, 2, 0).numpy()
        diff = np.abs(clean-denoised)
        diff_heatmap = np.mean(diff, axis=2)

        # Subplot for Clean Image
        plt.subplot(num_worst, 5, i*5 + 1)
        plt.imshow(clean)
        plt.title(f"Target (Clean)\nIndex : {item['index']}")
        plt.axis('off')

        # Subplot for Noisy Input Image
        psnr_noisy = calculate_PSNR(item['inputs'].squeeze(), item['targets'].squeeze()).item()
        plt.subplot(num_worst, 5, i*5 + 2)
        plt.imshow(noisy)
        plt.title(f"Noisy Input\nPSNR : {psnr_noisy:.2f}dB")
        plt.axis('off')

        # Subplot for Denoised Image
        plt.subplot(num_worst, 5, i*5 + 3)
        plt.imshow(denoised)
        plt.title(f"Denoised Image\nPSNR : {item['PSNR']:.2f}dB")
        plt.axis('off')


        # Subplot for Difference Heatmap
        plt.subplot(num_worst, 5, i*5 + 4)
        plt.imshow(diff_heatmap, cmap='gray', vmin=0, vmax=0.2)
        plt.title("Difference Heatmap")
        plt.axis('off')

        # Subplot for Error Heatmap
        plt.subplot(num_worst, 5, i*5 + 5)
        plt.imshow(diff_heatmap, cmap='jet', vmin=0, vmax=0.1)
        plt.title("Error Heatmap")
        plt.axis('off')

    plt.tight_layout()
    plt.show()

worst_case(model, val_loader, num_worst=5)

# %%
def best_case(model, val_loader, num_best=5, mode='worst'):
    model.eval()
    all_results = []

    with torch.no_grad():
        global_index = 0
        for inputs, targets, _ in val_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            denoised = torch.clamp(inputs - outputs, 0.0, 1.0)

            # 배치 내의 각 이미지에 대해 반복
            for b in range(inputs.size(0)):
                # 단일 이미지에 대한 PSNR 계산
                PSNR = calculate_PSNR(
                    denoised[b], targets[b]
                ).item()

                all_results.append({
                    'index' : global_index,
                    'PSNR' : PSNR,
                    'inputs' : inputs[b].cpu(),       # Shape: (C, H, W)
                    'targets' : targets[b].cpu(),
                    'denoised_img' : denoised[b].cpu()
                })
                global_index += 1

    reverse = True if mode == 'best' else False
    all_results.sort(key=lambda x: x['PSNR'], reverse=reverse)

    selected_cases = all_results[:num_best]

    plt.figure(figsize=(20, 5 * num_best))

    for i, item in enumerate(selected_cases):
        # 1. 텐서 차원 변환: (C, H, W) -> (H, W, C)
        clean = item['targets'].permute(1, 2, 0).numpy()
        noisy = item['inputs'].permute(1, 2, 0).numpy()
        denoised = item['denoised_img'].permute(1, 2, 0).numpy()
        diff = np.abs(clean - denoised)
        diff_heatmap = np.mean(diff, axis=2) # (H, W, 3) -> (H, W)로 변환

        plt.subplot(num_best, 5, i*5 + 1)
        plt.imshow(clean)
        plt.title(f"Target (Clean)\nIndex : {item['index']}")
        plt.axis('off')

        psnr_noisy = calculate_PSNR(item['inputs'], item['targets']).item()
        plt.subplot(num_best, 5, i*5 + 2)
        plt.imshow(noisy)
        plt.title(f"Noisy Input\nPSNR : {psnr_noisy:.2f}dB")
        plt.axis('off')

        plt.subplot(num_best, 5, i*5 + 3)
        plt.imshow(denoised)
        plt.title(f"Denoised Output\nPSNR : {item['PSNR']:.2f}dB")
        plt.axis('off')

        plt.subplot(num_best, 5, i*5 + 4)
        plt.imshow(diff_heatmap, cmap='gray', vmin=0, vmax=0.2)
        plt.title("Difference Heatmap")
        plt.axis('off')

        plt.subplot(num_best, 5, i*5 + 5)
        plt.imshow(diff_heatmap, cmap='jet', vmin=0, vmax=0.1)
        plt.title("Error Heatmap")
        plt.axis('off')

    plt.tight_layout()
    plt.show()

best_case(model, val_loader, num_best=5, mode='best')
